# %% [markdown]
# # Avaliação de Redes Complexas

# %% [markdown]
# Nome: Vítor Amorim Fróis
# NUSP: 12543440

# %% [markdown]
# <hr>

# %% [markdown]
# Inicialmente são feitos imports e funções que serão utilizadas ao longo do notebook.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import math
import EoN
import random as random
import statistics as stat
import scipy

# %%
def process_graph(G):
    G = G.to_undirected()
    G.remove_edges_from(nx.selfloop_edges(G))
    Gcc = sorted(nx.connected_components(G), key=len, reverse=True)
    G = G.subgraph(Gcc[0])
    G = nx.convert_node_labels_to_integers(G)
    return G

# %%
def shannon_entropy(G):
    k,Pk = degree_distribution(G)
    H = 0
    for p in Pk:
        if(p > 0):
            H = H - p*math.log(p, 2)
    return H

# %%
def get_all_degrees(G):
  degrees = []
  for node in G.nodes:
    degrees.append(G.degree[node])
  return degrees

# %%
def degree_distribution(G):
    vk = dict(G.degree())
    vk = list(vk.values()) # we get only the degree values
    maxk = np.max(vk)
    mink = np.min(min)
    kvalues = np.arange(0,maxk+1) # possible values of k
    Pk = np.zeros(maxk+1) # P(k)
    for k in vk:
        Pk[k] = Pk[k] + 1
    Pk = Pk/sum(Pk) # the sum of the elements of P(k) must to be equal to one
    return kvalues,Pk

# %%
def momment(G,m):
    M = 0
    N = len(G)
    for i in G.nodes:
        M = M + G.degree(i)**m
    M = M/N**m
    return M

# %% [markdown]
# **1 -** (a) Crie o gráfo a seguir usando a biblioteca networkx e mostre o gráfo.<br>
# Link para visualizar o grafo: https://commons.wikimedia.org/wiki/File:6n-graf.png<br>

# %%
G = nx.Graph()
edge_list = [(1, 2), (2, 3), (3, 4), (1, 5), (4, 5), (4, 6)]
G.add_edges_from(edge_list)

# %%
plt.figure(1,figsize=(3,3)) 
nx.draw(G, with_labels=True, node_size=1000)

# %% [markdown]
# (b) Simule uma caminha aleatória nesse grafo e monte uma matriz onde o elemento Mij representa o número de visitas ao vértice j dado que a caminhada iniciou em i. Considere pelo menos 100 passos. Compare o número de visitas com a medida eigenvector centrality de cada vértice.

# %%
nodes_list = list(G.nodes())
n_nodes = (len(nodes_list))
M = []
T = 100
for seed_node in nodes_list:
    ng = G.neighbors(seed_node)
    walk_p = np.zeros(n_nodes)
    for t in range(0,T):
        next_node = random.choice(list(ng))
        ng = G.neighbors(next_node)
        walk_p[next_node - 1] += 1
    M.append(walk_p)
M = np.array(M)
print(f'Matriz M: \n{M}')
M_sum = np.sum(M, axis=0)
print(f'A soma das colunas representa o total de vezes que o vértice foi visitado durante as iterações: \n{M_sum}')
# Out:
# Matriz M:
# [[22. 17. 12. 21. 19.  9.]
#  [11. 15. 21. 30. 17.  6.]
#  [20. 16. 13. 24. 18.  9.]
#  [18. 15. 15. 24. 18. 10.]
#  [13. 16. 20. 27. 16.  8.]
#  [29. 22.  9. 16. 18.  6.]]
# A soma das colunas representa o total de vezes que o vértice foi visitado durante as iterações:
# [113. 101.  90. 142. 106.  48.]

# %%
eig = list(nx.eigenvector_centrality(G).values())
eig
# Out:
# [0.3851210254201053,
#  0.3851210254201053,
#  0.4293744388249957,
#  0.5229658034947686,
#  0.4293744388249957,
#  0.24727624734544199]

# %%
stat.correlation(M_sum, eig)
# Out:
# 0.9178416854206368

# %% [markdown]
# Ao checar a correlação entre os dois métodos, obtemos um valor alto. Isso se deve ao fato de que os valores foram obtidos para uma mesma medida através de caminhos diferentes (método iterativo e da potência).

# %% [markdown]
# <hr>

# %% [markdown]
# **2 -** (a) Leia a rede do arquivo advogato.txt e mostre a distribuição acumulada complementar do grau, isto é, $P(K > k)$.

# %%
G = nx.convert_node_labels_to_integers(nx.read_edgelist('data-prova/advogato.txt'))

# %%
k, Pk = degree_distribution(G)
inv_cumsum = 1 - np.cumsum(Pk)

# %%
# determine best fit line

plt.loglog(k, inv_cumsum, 'o')

print(xl, yl)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.xlabel('k')
plt.ylabel('Pa(k)')
plt.title('Distribuição acumulada complementar do grau')
plt.show()
# Out:
# [0, 805] [0.0, 0.9432282546238216]

# %% [markdown]
# Pelo gráfico, é possível perceber uma distribuição baseada na lei de potência, indicando que a rede possui baixa homofilia. Podemos confirmar isso com o coeficiente de assortatividade.

# %%
nx.degree_assortativity_coefficient(G)
# Out:
# -0.07694795994236779

# %% [markdown]
# (b) Mostre o gráfico de Knn(k), ou seja, o grau médio dos vizinhos dos vértices de grau k em função do grau k.

# %%
knn = np.array(list(nx.average_neighbor_degree(G, nodes=G.nodes()).values()))

vk = dict(G.degree())
vk = list(vk.values())

knnk = list()
ks = list()
for k in np.arange(np.min(vk), np.max(vk)+1):
    aux = vk == k
    if(len(knn[aux]) > 0):
        av_knn = np.mean(knn[aux]) #average clustering among all the nodes with degree k
        knnk.append(av_knn)
        ks.append(k)
        
fig = plt.figure(figsize=(10,6))

# %%
plt.xlabel('ks')
plt.ylabel('knnk')
plt.title('Grau médio dos vizinhos dos vértices de grau k em função do grau k')
plt.plot(ks, knnk, 'o')

# %% [markdown]
# (c) Calcule a matriz de menores distâncias $D$ a matriz $A^n$, que presenta o número de caminhadas de comprimento $n$ entre cada par de vértices. Faça um gráfico da correlação entre $D_{ij}$ e $A_{ij}$ para diferentes valores de $n$. Ou seja, um gráfico em que o eixo x representa n e o y, a correlação entre essas duas matrizes.

# %%
G = process_graph(G)
array = nx.to_numpy_array(G)
csr = scipy.sparse.csr_matrix(array)
D = (scipy.sparse.csgraph.shortest_path(csr))
D_elements = D.flatten()

# %%
A = array

# %%
x = []
y = []

A = array

for n in range(5):
    x.append(n)
    A_power = np.linalg.matrix_power(A, 2)
    A_elements = A_power.flatten()
    y.append(stat.correlation(A_elements, D_elements))
    A = A_power

# %%
plt.xlabel('n')
plt.ylabel('Correlação entre $A^n$ e $D$')
plt.title('Correlação entre $A^n$ e $D$ por $n$')
plt.plot(x, y, 'b')
plt.figure(figsize=(10,6))

# %% [markdown]
# <hr>

# %% [markdown]
# **3 -** Considere a rede do arquivo internet_routers-22july06.gml. Escreva um código que calcule as seguintes medidas: (a) grau médio, (b) transitividade, (c) segundo momento da distribuição do grau, (d) entropia de Shannon da distribuição do grau, (e) coeficiente de assortatividade. Considere apenas o maior componente. Armazene os valores em uma lista e imprima essa lista, indicando os valores de cada medida.

# %%
routers = nx.read_gml('data-prova/internet_routers-22july06.gml')

# %%
average_degree = momment(G, 1)
transitivity = nx.transitivity(G)
G_momment = momment(G, 2)
G_shannon = shannon_entropy(G)
G_assortativity = nx.degree_assortativity_coefficient(G)

# %%
print('Grau médio: ', average_degree)
print('Transitividade: ', transitivity)
print('Segundo momento do grau: ', G_momment)
print('Entropia de Shannon: ', G_shannon)
print('Coeficiente de assortatividade: ', G_assortativity)
# Out:
# Grau médio:  4.218612550624918
# Transitividade:  0.011146383847822162
# Segundo momento do grau:  0.048033802976160965
# Entropia de Shannon:  2.3657964585920395
# Coeficiente de assortatividade:  -0.1983848751205647

# %% [markdown]
# <hr>

# %% [markdown]
# **4 -** Simule o modelo de propagação de epidemias SIR na rede de aeroportos dos EUA (USairport_2010.txt). Calcule a correlação de Pearson entre a fração final de recuperados e as seguintes medidas de centralidade: (a) grau, (b) betweenness centrality, (c) eigenvector centrality, (d) closenness centrality. Mostre os resultados e indique a maior correlação. Considere $\beta = 0.6$ e $\mu = 0.1$ no modelo SIR.

# %%
G = nx.read_edgelist('data-prova/USairport_2010.txt')

# %%
beta = 0.3
mi = 0.1
seed_list = list(G.nodes())
n = len(seed_list)
R_rate_list = []
degree_list = []
bet_list = []
eigen_list = []
close_list = []

# %%
all_deg_list = nx.degree(G)
all_eig_list = nx.eigenvector_centrality(G)
all_bet_list = nx.betweenness_centrality(G)
all_close_list = nx.closeness_centrality(G)

# %%
for seed in seed_list:
    times, S, I, R = EoN.fast_SIR(G, beta, mi, [seed])
    degree_list.append(all_deg_list[seed])
    bet_list.append(all_eig_list[seed])
    eigen_list.append(all_eig_list[seed])
    close_list.append(all_close_list[seed])
    R_rate_list.append(R[-1]/n)
    print(f'Last time info (seed = {seed}): {S[-1]}, {I[-1]}, {R[-1]}')
# Out:
# Last time info (seed = 0): 299, 0, 4743
# Last time info (seed = 1): 325, 0, 4717
# Last time info (seed = 2): 258, 0, 4784
# Last time info (seed = 3): 295, 0, 4747
# Last time info (seed = 4): 369, 0, 4673
# Last time info (seed = 5): 5041, 0, 1
# Last time info (seed = 6): 321, 0, 4721
# Last time info (seed = 7): 343, 0, 4699
# Last time info (seed = 8): 348, 0, 4694
# Last time info (seed = 9): 5041, 0, 1
# Last time info (seed = 10): 319, 0, 4723
# Last time info (seed = 11): 327, 0, 4715
# Last time info (seed = 12): 366, 0, 4676
# Last time info (seed = 13): 361, 0, 4681
# Last time info (seed = 14): 309, 0, 4733
# Last time info (seed = 15): 347, 0, 4695
# Last time info (seed = 16): 288, 0, 4754
# Last time info (seed = 17): 374, 0, 4668
# Last time info (seed = 18): 332, 0, 4710
# Last time info (seed = 19): 282, 0, 4760
# Last time info (seed = 20): 282, 0, 4760
# Last time info (seed = 21): 313, 0, 4729
# Last time info (seed = 22): 333, 0, 4709
# Last time info (seed = 23): 335, 0, 4707
# Last time info (seed = 24): 319, 0, 4723
# Last time info (seed = 25): 344, 0, 4698
# Last time info (seed = 26): 284, 0, 4758
# Last time info (seed = 27): 360, 0, 4682
# Last time info (seed = 28): 305, 0, 4737
# Last time info (seed = 29): 277, 0, 4765
# Last time info (seed = 30): 304, 0, 4738
# Last time info (seed = 31): 351, 0, 4691
# Last time info (seed = 32): 377, 0, 4665
# Last time info (seed = 33): 5041, 0, 1
# Last time info (seed = 34): 282, 0, 4760
# Last time info (seed = 35): 326, 0, 4716
# Last time info (seed = 36): 305, 0, 4737
# Last time info (seed = 37): 318, 0, 4724
# Last time info (seed = 38): 300, 0, 4742
# Last time info (seed = 39): 302, 0, 4740
# Last time info (seed = 40): 320, 0, 4722
# Last time info (seed = 41): 331, 0, 4711
# Last time info (seed = 42): 293, 0, 4749
# Last time info (seed = 43): 305, 0, 4737
# Last time info (seed = 44): 333, 0, 4709
# Last time info (seed = 45): 326, 0, 4716
# Last time info (seed = 46): 316, 0, 4726
# Last time info (seed = 47): 364, 0, 4678
# Last time info (seed = 48): 297, 0, 4745
# Last time info (seed = 49): 389, 0, 4653
# Last time info (seed = 50): 373, 0, 4669
# Last time info (seed = 51): 303, 0, 4739
# Last time info (seed = 52): 304, 0, 4738
# Last time info (seed = 53): 339, 0, 4703
# Last time info (seed = 54): 350, 0, 4692
# Last time info (seed = 55): 334, 0, 4708
# Last time info (seed = 56): 335, 0, 4707
# Last time info (seed = 57): 364, 0, 4678
# Last time info (seed = 58): 311, 0, 4731
# Last time info (seed = 59): 367, 0, 4675
# Last time info (seed = 60): 360, 0, 4682
# Last time info (seed = 61): 345, 0, 4697
# Last time info (seed = 62): 354, 0, 4688
# Last time info (seed = 63): 242, 0, 4800
# Last time info (seed = 64): 265, 0, 4777
# Last time info (seed = 65): 317, 0, 4725
# Last time info (seed = 66): 285, 0, 4757
# Last time info (seed = 67): 364, 0, 4678
# Last time info (seed = 68): 295, 0, 4747
# Last time info (seed = 69): 364, 0, 4678
# Last time info (seed = 70): 282, 0, 4760
# Last time info (seed = 71): 5041, 0, 1
# Last time info (seed = 72): 345, 0, 4697
# Last time info (seed = 73): 309, 0, 4733
# Last time info (seed = 74): 298, 0, 4744
# Last time info (seed = 75): 326, 0, 4716
# Last time info (seed = 76): 318, 0, 4724
# Last time info (seed = 77): 314, 0, 4728
# Last time info (seed = 78): 312, 0, 4730
# Last time info (seed = 79): 314, 0, 4728
# Last time info (seed = 80): 347, 0, 4695
# Last time info (seed = 81): 315, 0, 4727
# Last time info (seed = 82): 290, 0, 4752
# Last time info (seed = 83): 303, 0, 4739
# Last time info (seed = 84): 319, 0, 4723
# Last time info (seed = 85): 357, 0, 4685
# Last time info (seed = 86): 347, 0, 4695
# Last time info (seed = 87): 310, 0, 4732
# Last time info (seed = 88): 423, 0, 4619
# Last time info (seed = 89): 376, 0, 4666
# Last time info (seed = 90): 260, 0, 4782
# Last time info (seed = 91): 343, 0, 4699
# Last time info (seed = 92): 312, 0, 4730
# Last time info (seed = 93): 308, 0, 4734
# Last time info (seed = 94): 378, 0, 4664
# Last time info (seed = 95): 340, 0, 4702
# Last time info (seed = 96): 299, 0, 4743
# Last time info (seed = 97): 311, 0, 4731
# Last time info (seed = 98): 291, 0, 4751
# Last time info (seed = 99): 329, 0, 4713
# Last time info (seed = 100): 364, 0, 4678
# Last time info (seed = 101): 323, 0, 4719
# Last time info (seed = 102): 286, 0, 4756
# Last time info (seed = 103): 365, 0, 4677
# Last time info (seed = 104): 292, 0, 4750
# Last time info (seed = 105): 374, 0, 4668
# Last time info (seed = 106): 401, 0, 4641
# Last time info (seed = 107): 337, 0, 4705
# Last time info (seed = 108): 343, 0, 4699
# Last time info (seed = 109): 5041, 0, 1
# Last time info (seed = 110): 282, 0, 4760
# Last time info (seed = 111): 281, 0, 4761
# Last time info (seed = 112): 351, 0, 4691
# Last time info (seed = 113): 309, 0, 4733
# Last time info (seed = 114): 398, 0, 4644
# Last time info (seed = 115): 333, 0, 4709
# Last time info (seed = 116): 327, 0, 4715
# Last time info (seed = 117): 344, 0, 4698
# Last time info (seed = 118): 245, 0, 4797
# Last time info (seed = 119): 389, 0, 4653
# Last time info (seed = 120): 316, 0, 4726
# Last time info (seed = 121): 287, 0, 4755
# Last time info (seed = 122): 299, 0, 4743
# Last time info (seed = 123): 341, 0, 4701
# Last time info (seed = 124): 293, 0, 4749
# Last time info (seed = 125): 274, 0, 4768
# Last time info (seed = 126): 304, 0, 4738
# Last time info (seed = 127): 339, 0, 4703
# Last time info (seed = 128): 338, 0, 4704
# Last time info (seed = 129): 296, 0, 4746
# Last time info (seed = 130): 303, 0, 4739
# Last time info (seed = 131): 281, 0, 4761
# Last time info (seed = 132): 282, 0, 4760
# Last time info (seed = 133): 270, 0, 4772
# Last time info (seed = 134): 5041, 0, 1
# Last time info (seed = 135): 332, 0, 4710
# Last time info (seed = 136): 351, 0, 4691
# Last time info (seed = 137): 306, 0, 4736
# Last time info (seed = 138): 5041, 0, 1
# Last time info (seed = 139): 316, 0, 4726
# Last time info (seed = 140): 337, 0, 4705
# Last time info (seed = 141): 332, 0, 4710
# Last time info (seed = 142): 369, 0, 4673
# Last time info (seed = 143): 294, 0, 4748
# Last time info (seed = 144): 334, 0, 4708
# Last time info (seed = 145): 299, 0, 4743
# Last time info (seed = 146): 323, 0, 4719
# Last time info (seed = 147): 282, 0, 4760
# Last time info (seed = 148): 310, 0, 4732
# Last time info (seed = 149): 340, 0, 4702
# Last time info (seed = 150): 345, 0, 4697
# Last time info (seed = 151): 343, 0, 4699
# Last time info (seed = 152): 293, 0, 4749
# Last time info (seed = 153): 5041, 0, 1
# Last time info (seed = 154): 290, 0, 4752
# Last time info (seed = 155): 301, 0, 4741
# Last time info (seed = 156): 339, 0, 4703
# Last time info (seed = 157): 323, 0, 4719
# Last time info (seed = 158): 326, 0, 4716
# Last time info (seed = 159): 346, 0, 4696
# Last time info (seed = 160): 294, 0, 4748
# Last time info (seed = 161): 289, 0, 4753
# Last time info (seed = 162): 278, 0, 4764
# Last time info (seed = 163): 323, 0, 4719
# Last time info (seed = 164): 355, 0, 4687
# Last time info (seed = 165): 284, 0, 4758
# Last time info (seed = 166): 340, 0, 4702
# Last time info (seed = 167): 348, 0, 4694
# Last time info (seed = 168): 267, 0, 4775
# Last time info (seed = 169): 369, 0, 4673
# Last time info (seed = 170): 278, 0, 4764
# Last time info (seed = 171): 292, 0, 4750
# Last time info (seed = 172): 326, 0, 4716
# Last time info (seed = 173): 371, 0, 4671
# Last time info (seed = 174): 336, 0, 4706
# Last time info (seed = 175): 317, 0, 4725
# Last time info (seed = 176): 5041, 0, 1
# Last time info (seed = 177): 326, 0, 4716
# Last time info (seed = 178): 369, 0, 4673
# Last time info (seed = 179): 359, 0, 4683
# Last time info (seed = 180): 360, 0, 4682
# Last time info (seed = 181): 325, 0, 4717
# Last time info (seed = 182): 328, 0, 4714
# Last time info (seed = 183): 348, 0, 4694
# Last time info (seed = 184): 291, 0, 4751
# Last time info (seed = 185): 402, 0, 4640
# Last time info (seed = 186): 310, 0, 4732
# Last time info (seed = 187): 340, 0, 4702
# Last time info (seed = 188): 295, 0, 4747
# Last time info (seed = 189): 324, 0, 4718
# Last time info (seed = 190): 324, 0, 4718
# Last time info (seed = 191): 302, 0, 4740
# Last time info (seed = 192): 373, 0, 4669
# Last time info (seed = 193): 5041, 0, 1
# Last time info (seed = 194): 290, 0, 4752
# Last time info (seed = 195): 316, 0, 4726
# Last time info (seed = 196): 301, 0, 4741
# Last time info (seed = 197): 391, 0, 4651
# Last time info (seed = 198): 277, 0, 4765
# Last time info (seed = 199): 322, 0, 4720
# Last time info (seed = 200): 304, 0, 4738
# Last time info (seed = 201): 343, 0, 4699
# Last time info (seed = 202): 321, 0, 4721
# Last time info (seed = 203): 341, 0, 4701
# Last time info (seed = 204): 293, 0, 4749
# Last time info (seed = 205): 325, 0, 4717
# Last time info (seed = 206): 318, 0, 4724
# Last time info (seed = 207): 294, 0, 4748
# Last time info (seed = 208): 344, 0, 4698
# Last time info (seed = 209): 291, 0, 4751
# Last time info (seed = 210): 341, 0, 4701
# Last time info (seed = 211): 330, 0, 4712
# Last time info (seed = 212): 353, 0, 4689
# Last time info (seed = 213): 338, 0, 4704
# Last time info (seed = 214): 440, 0, 4602
# Last time info (seed = 215): 333, 0, 4709
# Last time info (seed = 216): 356, 0, 4686
# Last time info (seed = 217): 350, 0, 4692
# Last time info (seed = 218): 5041, 0, 1
# Last time info (seed = 219): 344, 0, 4698
# Last time info (seed = 220): 366, 0, 4676
# Last time info (seed = 221): 317, 0, 4725
# Last time info (seed = 222): 377, 0, 4665
# Last time info (seed = 223): 277, 0, 4765
# Last time info (seed = 224): 418, 0, 4624
# Last time info (seed = 225): 261, 0, 4781
# Last time info (seed = 226): 310, 0, 4732
# Last time info (seed = 227): 307, 0, 4735
# Last time info (seed = 228): 363, 0, 4679
# Last time info (seed = 229): 275, 0, 4767
# Last time info (seed = 230): 343, 0, 4699
# Last time info (seed = 231): 330, 0, 4712
# Last time info (seed = 232): 373, 0, 4669
# Last time info (seed = 233): 292, 0, 4750
# Last time info (seed = 234): 366, 0, 4676
# Last time info (seed = 235): 364, 0, 4678
# Last time info (seed = 236): 341, 0, 4701
# Last time info (seed = 237): 313, 0, 4729
# Last time info (seed = 238): 337, 0, 4705
# Last time info (seed = 239): 333, 0, 4709
# Last time info (seed = 240): 334, 0, 4708
# Last time info (seed = 241): 306, 0, 4736
# Last time info (seed = 242): 316, 0, 4726
# Last time info (seed = 243): 302, 0, 4740
# Last time info (seed = 244): 271, 0, 4771
# Last time info (seed = 245): 326, 0, 4716
# Last time info (seed = 246): 328, 0, 4714
# Last time info (seed = 247): 360, 0, 4682
# Last time info (seed = 248): 346, 0, 4696
# Last time info (seed = 249): 337, 0, 4705
# Last time info (seed = 250): 341, 0, 4701
# Last time info (seed = 251): 343, 0, 4699
# Last time info (seed = 252): 294, 0, 4748
# Last time info (seed = 253): 257, 0, 4785
# Last time info (seed = 254): 5041, 0, 1
# Last time info (seed = 255): 324, 0, 4718
# Last time info (seed = 256): 286, 0, 4756
# Last time info (seed = 257): 294, 0, 4748
# Last time info (seed = 258): 347, 0, 4695
# Last time info (seed = 259): 303, 0, 4739
# Last time info (seed = 260): 281, 0, 4761
# Last time info (seed = 261): 334, 0, 4708
# Last time info (seed = 262): 308, 0, 4734
# Last time info (seed = 263): 302, 0, 4740
# Last time info (seed = 264): 284, 0, 4758
# Last time info (seed = 265): 344, 0, 4698
# Last time info (seed = 266): 384, 0, 4658
# Last time info (seed = 267): 353, 0, 4689
# Last time info (seed = 268): 335, 0, 4707
# Last time info (seed = 269): 333, 0, 4709
# Last time info (seed = 270): 319, 0, 4723
# Last time info (seed = 271): 339, 0, 4703
# Last time info (seed = 272): 314, 0, 4728
# Last time info (seed = 273): 330, 0, 4712
# Last time info (seed = 274): 282, 0, 4760
# Last time info (seed = 275): 331, 0, 4711
# Last time info (seed = 276): 348, 0, 4694
# Last time info (seed = 277): 274, 0, 4768
# Last time info (seed = 278): 338, 0, 4704
# Last time info (seed = 279): 331, 0, 4711
# Last time info (seed = 280): 401, 0, 4641
# Last time info (seed = 281): 293, 0, 4749
# Last time info (seed = 282): 267, 0, 4775
# Last time info (seed = 283): 338, 0, 4704
# Last time info (seed = 284): 346, 0, 4696
# Last time info (seed = 285): 277, 0, 4765
# Last time info (seed = 286): 332, 0, 4710
# Last time info (seed = 287): 284, 0, 4758
# Last time info (seed = 288): 304, 0, 4738
# Last time info (seed = 289): 293, 0, 4749
# Last time info (seed = 290): 399, 0, 4643
# Last time info (seed = 291): 297, 0, 4745
# Last time info (seed = 292): 353, 0, 4689
# Last time info (seed = 293): 263, 0, 4779
# Last time info (seed = 294): 276, 0, 4766
# Last time info (seed = 295): 331, 0, 4711
# Last time info (seed = 296): 308, 0, 4734
# Last time info (seed = 297): 319, 0, 4723
# Last time info (seed = 298): 312, 0, 4730
# Last time info (seed = 299): 307, 0, 4735
# Last time info (seed = 300): 336, 0, 4706
# Last time info (seed = 301): 312, 0, 4730
# Last time info (seed = 302): 321, 0, 4721
# Last time info (seed = 303): 361, 0, 4681
# Last time info (seed = 304): 291, 0, 4751
# Last time info (seed = 305): 319, 0, 4723
# Last time info (seed = 306): 314, 0, 4728
# Last time info (seed = 307): 349, 0, 4693
# Last time info (seed = 308): 276, 0, 4766
# Last time info (seed = 309): 317, 0, 4725
# Last time info (seed = 310): 293, 0, 4749
# Last time info (seed = 311): 354, 0, 4688
# Last time info (seed = 312): 347, 0, 4695
# Last time info (seed = 313): 373, 0, 4669
# Last time info (seed = 314): 318, 0, 4724
# Last time info (seed = 315): 362, 0, 4680
# Last time info (seed = 316): 358, 0, 4684
# Last time info (seed = 317): 345, 0, 4697
# Last time info (seed = 318): 334, 0, 4708
# Last time info (seed = 319): 257, 0, 4785
# Last time info (seed = 320): 361, 0, 4681
# Last time info (seed = 321): 303, 0, 4739
# Last time info (seed = 322): 352, 0, 4690
# Last time info (seed = 323): 298, 0, 4744
# Last time info (seed = 324): 328, 0, 4714
# Last time info (seed = 325): 359, 0, 4683
# Last time info (seed = 326): 328, 0, 4714
# Last time info (seed = 327): 402, 0, 4640
# Last time info (seed = 328): 337, 0, 4705
# Last time info (seed = 329): 5041, 0, 1
# Last time info (seed = 330): 357, 0, 4685
# Last time info (seed = 331): 5041, 0, 1
# Last time info (seed = 332): 311, 0, 4731
# Last time info (seed = 333): 362, 0, 4680
# Last time info (seed = 334): 261, 0, 4781
# Last time info (seed = 335): 303, 0, 4739
# Last time info (seed = 336): 402, 0, 4640
# Last time info (seed = 337): 364, 0, 4678
# Last time info (seed = 338): 313, 0, 4729
# Last time info (seed = 339): 328, 0, 4714
# Last time info (seed = 340): 327, 0, 4715
# Last time info (seed = 341): 314, 0, 4728
# Last time info (seed = 342): 367, 0, 4675
# Last time info (seed = 343): 310, 0, 4732
# Last time info (seed = 344): 288, 0, 4754
# Last time info (seed = 345): 319, 0, 4723
# Last time info (seed = 346): 306, 0, 4736
# Last time info (seed = 347): 411, 0, 4631
# Last time info (seed = 348): 5041, 0, 1
# Last time info (seed = 349): 359, 0, 4683
# Last time info (seed = 350): 293, 0, 4749
# Last time info (seed = 351): 5041, 0, 1
# Last time info (seed = 352): 317, 0, 4725
# Last time info (seed = 353): 303, 0, 4739
# Last time info (seed = 354): 304, 0, 4738
# Last time info (seed = 355): 335, 0, 4707
# Last time info (seed = 356): 393, 0, 4649
# Last time info (seed = 357): 300, 0, 4742
# Last time info (seed = 358): 314, 0, 4728
# Last time info (seed = 359): 316, 0, 4726
# Last time info (seed = 360): 314, 0, 4728
# Last time info (seed = 361): 356, 0, 4686
# Last time info (seed = 362): 316, 0, 4726
# Last time info (seed = 363): 364, 0, 4678
# Last time info (seed = 364): 279, 0, 4763
# Last time info (seed = 365): 347, 0, 4695
# Last time info (seed = 366): 327, 0, 4715
# Last time info (seed = 367): 326, 0, 4716
# Last time info (seed = 368): 334, 0, 4708
# Last time info (seed = 369): 322, 0, 4720
# Last time info (seed = 370): 363, 0, 4679
# Last time info (seed = 371): 286, 0, 4756
# Last time info (seed = 372): 289, 0, 4753
# Last time info (seed = 373): 5041, 0, 1
# Last time info (seed = 374): 277, 0, 4765
# Last time info (seed = 375): 325, 0, 4717
# Last time info (seed = 376): 332, 0, 4710
# Last time info (seed = 377): 330, 0, 4712
# Last time info (seed = 378): 314, 0, 4728
# Last time info (seed = 379): 364, 0, 4678
# Last time info (seed = 380): 329, 0, 4713
# Last time info (seed = 381): 342, 0, 4700
# Last time info (seed = 382): 291, 0, 4751
# Last time info (seed = 383): 330, 0, 4712
# Last time info (seed = 384): 313, 0, 4729
# Last time info (seed = 385): 368, 0, 4674
# Last time info (seed = 386): 320, 0, 4722
# Last time info (seed = 387): 310, 0, 4732
# Last time info (seed = 388): 283, 0, 4759
# Last time info (seed = 389): 5041, 0, 1
# Last time info (seed = 390): 380, 0, 4662
# Last time info (seed = 391): 361, 0, 4681
# Last time info (seed = 392): 303, 0, 4739
# Last time info (seed = 393): 287, 0, 4755
# Last time info (seed = 394): 309, 0, 4733
# Last time info (seed = 395): 289, 0, 4753
# Last time info (seed = 396): 304, 0, 4738
# Last time info (seed = 397): 279, 0, 4763
# Last time info (seed = 398): 371, 0, 4671
# Last time info (seed = 399): 301, 0, 4741
# Last time info (seed = 400): 323, 0, 4719
# Last time info (seed = 401): 347, 0, 4695
# Last time info (seed = 402): 332, 0, 4710
# Last time info (seed = 403): 317, 0, 4725
# Last time info (seed = 404): 341, 0, 4701
# Last time info (seed = 405): 314, 0, 4728
# Last time info (seed = 406): 316, 0, 4726
# Last time info (seed = 407): 309, 0, 4733
# Last time info (seed = 408): 270, 0, 4772
# Last time info (seed = 409): 317, 0, 4725
# Last time info (seed = 410): 303, 0, 4739
# Last time info (seed = 411): 390, 0, 4652
# Last time info (seed = 412): 338, 0, 4704
# Last time info (seed = 413): 348, 0, 4694
# Last time info (seed = 414): 360, 0, 4682
# Last time info (seed = 415): 304, 0, 4738
# Last time info (seed = 416): 244, 0, 4798
# Last time info (seed = 417): 330, 0, 4712
# Last time info (seed = 418): 335, 0, 4707
# Last time info (seed = 419): 364, 0, 4678
# Last time info (seed = 420): 304, 0, 4738
# Last time info (seed = 421): 330, 0, 4712
# Last time info (seed = 422): 309, 0, 4733
# Last time info (seed = 423): 356, 0, 4686
# Last time info (seed = 424): 340, 0, 4702
# Last time info (seed = 425): 273, 0, 4769
# Last time info (seed = 426): 310, 0, 4732
# Last time info (seed = 427): 349, 0, 4693
# Last time info (seed = 428): 339, 0, 4703
# Last time info (seed = 429): 362, 0, 4680
# Last time info (seed = 430): 278, 0, 4764
# Last time info (seed = 431): 359, 0, 4683
# Last time info (seed = 432): 330, 0, 4712
# Last time info (seed = 433): 357, 0, 4685
# Last time info (seed = 434): 346, 0, 4696
# Last time info (seed = 435): 385, 0, 4657
# Last time info (seed = 436): 360, 0, 4682
# Last time info (seed = 437): 373, 0, 4669
# Last time info (seed = 438): 366, 0, 4676
# Last time info (seed = 439): 299, 0, 4743
# Last time info (seed = 440): 339, 0, 4703
# Last time info (seed = 441): 349, 0, 4693
# Last time info (seed = 442): 364, 0, 4678
# Last time info (seed = 443): 348, 0, 4694
# Last time info (seed = 444): 343, 0, 4699
# Last time info (seed = 445): 323, 0, 4719
# Last time info (seed = 446): 360, 0, 4682
# Last time info (seed = 447): 334, 0, 4708
# Last time info (seed = 448): 348, 0, 4694
# Last time info (seed = 449): 294, 0, 4748
# Last time info (seed = 450): 373, 0, 4669
# Last time info (seed = 451): 331, 0, 4711
# Last time info (seed = 452): 281, 0, 4761
# Last time info (seed = 453): 305, 0, 4737
# Last time info (seed = 454): 352, 0, 4690
# Last time info (seed = 455): 322, 0, 4720
# Last time info (seed = 456): 316, 0, 4726
# Last time info (seed = 457): 334, 0, 4708
# Last time info (seed = 458): 307, 0, 4735
# Last time info (seed = 459): 285, 0, 4757
# Last time info (seed = 460): 355, 0, 4687
# Last time info (seed = 461): 354, 0, 4688
# Last time info (seed = 462): 5041, 0, 1
# Last time info (seed = 463): 382, 0, 4660
# Last time info (seed = 464): 350, 0, 4692
# Last time info (seed = 465): 297, 0, 4745
# Last time info (seed = 466): 324, 0, 4718
# Last time info (seed = 467): 337, 0, 4705
# Last time info (seed = 468): 337, 0, 4705
# Last time info (seed = 469): 358, 0, 4684
# Last time info (seed = 470): 312, 0, 4730
# Last time info (seed = 471): 317, 0, 4725
# Last time info (seed = 472): 306, 0, 4736
# Last time info (seed = 473): 304, 0, 4738
# Last time info (seed = 474): 339, 0, 4703
# Last time info (seed = 475): 317, 0, 4725
# Last time info (seed = 476): 310, 0, 4732
# Last time info (seed = 477): 333, 0, 4709
# Last time info (seed = 478): 270, 0, 4772
# Last time info (seed = 479): 302, 0, 4740
# Last time info (seed = 480): 5041, 0, 1
# Last time info (seed = 481): 358, 0, 4684
# Last time info (seed = 482): 326, 0, 4716
# Last time info (seed = 483): 341, 0, 4701
# Last time info (seed = 484): 310, 0, 4732
# Last time info (seed = 485): 303, 0, 4739
# Last time info (seed = 486): 344, 0, 4698
# Last time info (seed = 487): 330, 0, 4712
# Last time info (seed = 488): 281, 0, 4761
# Last time info (seed = 489): 350, 0, 4692
# Last time info (seed = 490): 324, 0, 4718
# Last time info (seed = 491): 280, 0, 4762
# Last time info (seed = 492): 311, 0, 4731
# Last time info (seed = 493): 5041, 0, 1
# Last time info (seed = 494): 312, 0, 4730
# Last time info (seed = 495): 308, 0, 4734
# Last time info (seed = 496): 292, 0, 4750
# Last time info (seed = 497): 342, 0, 4700
# Last time info (seed = 498): 332, 0, 4710
# Last time info (seed = 499): 267, 0, 4775
# Last time info (seed = 500): 357, 0, 4685
# Last time info (seed = 501): 333, 0, 4709
# Last time info (seed = 502): 5041, 0, 1
# Last time info (seed = 503): 339, 0, 4703
# Last time info (seed = 504): 304, 0, 4738
# Last time info (seed = 505): 301, 0, 4741
# Last time info (seed = 506): 320, 0, 4722
# Last time info (seed = 507): 311, 0, 4731
# Last time info (seed = 508): 311, 0, 4731
# Last time info (seed = 509): 352, 0, 4690
# Last time info (seed = 510): 272, 0, 4770
# Last time info (seed = 511): 319, 0, 4723
# Last time info (seed = 512): 381, 0, 4661
# Last time info (seed = 513): 291, 0, 4751
# Last time info (seed = 514): 361, 0, 4681
# Last time info (seed = 515): 337, 0, 4705
# Last time info (seed = 516): 334, 0, 4708
# Last time info (seed = 517): 307, 0, 4735
# Last time info (seed = 518): 328, 0, 4714
# Last time info (seed = 519): 320, 0, 4722
# Last time info (seed = 520): 312, 0, 4730
# Last time info (seed = 521): 324, 0, 4718
# Last time info (seed = 522): 342, 0, 4700
# Last time info (seed = 523): 320, 0, 4722
# Last time info (seed = 524): 344, 0, 4698
# Last time info (seed = 525): 307, 0, 4735
# Last time info (seed = 526): 331, 0, 4711
# Last time info (seed = 527): 312, 0, 4730
# Last time info (seed = 528): 371, 0, 4671
# Last time info (seed = 529): 323, 0, 4719
# Last time info (seed = 530): 330, 0, 4712
# Last time info (seed = 531): 308, 0, 4734
# Last time info (seed = 532): 334, 0, 4708
# Last time info (seed = 533): 324, 0, 4718
# Last time info (seed = 534): 291, 0, 4751
# Last time info (seed = 535): 361, 0, 4681
# Last time info (seed = 536): 347, 0, 4695
# Last time info (seed = 537): 380, 0, 4662
# Last time info (seed = 538): 320, 0, 4722
# Last time info (seed = 539): 318, 0, 4724
# Last time info (seed = 540): 308, 0, 4734
# Last time info (seed = 541): 324, 0, 4718
# Last time info (seed = 542): 5041, 0, 1
# Last time info (seed = 543): 334, 0, 4708
# Last time info (seed = 544): 5041, 0, 1
# Last time info (seed = 545): 311, 0, 4731
# Last time info (seed = 546): 310, 0, 4732
# Last time info (seed = 547): 360, 0, 4682
# Last time info (seed = 548): 347, 0, 4695
# Last time info (seed = 549): 329, 0, 4713
# Last time info (seed = 550): 302, 0, 4740
# Last time info (seed = 551): 316, 0, 4726
# Last time info (seed = 552): 293, 0, 4749
# Last time info (seed = 553): 296, 0, 4746
# Last time info (seed = 554): 325, 0, 4717
# Last time info (seed = 555): 347, 0, 4695
# Last time info (seed = 556): 324, 0, 4718
# Last time info (seed = 557): 362, 0, 4680
# Last time info (seed = 558): 293, 0, 4749
# Last time info (seed = 559): 360, 0, 4682
# Last time info (seed = 560): 304, 0, 4738
# Last time info (seed = 561): 378, 0, 4664
# Last time info (seed = 562): 316, 0, 4726
# Last time info (seed = 563): 314, 0, 4728
# Last time info (seed = 564): 314, 0, 4728
# Last time info (seed = 565): 336, 0, 4706
# Last time info (seed = 566): 366, 0, 4676
# Last time info (seed = 567): 290, 0, 4752
# Last time info (seed = 568): 358, 0, 4684
# Last time info (seed = 569): 356, 0, 4686
# Last time info (seed = 570): 311, 0, 4731
# Last time info (seed = 571): 5041, 0, 1
# Last time info (seed = 572): 345, 0, 4697
# Last time info (seed = 573): 376, 0, 4666
# Last time info (seed = 574): 326, 0, 4716
# Last time info (seed = 575): 377, 0, 4665
# Last time info (seed = 576): 402, 0, 4640
# Last time info (seed = 577): 351, 0, 4691
# Last time info (seed = 578): 348, 0, 4694
# Last time info (seed = 579): 370, 0, 4672
# Last time info (seed = 580): 313, 0, 4729
# Last time info (seed = 581): 250, 0, 4792
# Last time info (seed = 582): 5041, 0, 1
# Last time info (seed = 583): 345, 0, 4697
# Last time info (seed = 584): 303, 0, 4739
# Last time info (seed = 585): 313, 0, 4729
# Last time info (seed = 586): 293, 0, 4749
# Last time info (seed = 587): 366, 0, 4676
# Last time info (seed = 588): 324, 0, 4718
# Last time info (seed = 589): 311, 0, 4731
# Last time info (seed = 590): 299, 0, 4743
# Last time info (seed = 591): 323, 0, 4719
# Last time info (seed = 592): 359, 0, 4683
# Last time info (seed = 593): 322, 0, 4720
# Last time info (seed = 594): 313, 0, 4729
# Last time info (seed = 595): 272, 0, 4770
# Last time info (seed = 596): 289, 0, 4753
# Last time info (seed = 597): 350, 0, 4692
# Last time info (seed = 598): 338, 0, 4704
# Last time info (seed = 599): 5041, 0, 1
# Last time info (seed = 600): 329, 0, 4713
# Last time info (seed = 601): 395, 0, 4647
# Last time info (seed = 602): 321, 0, 4721
# Last time info (seed = 603): 332, 0, 4710
# Last time info (seed = 604): 337, 0, 4705
# Last time info (seed = 605): 332, 0, 4710
# Last time info (seed = 606): 269, 0, 4773
# Last time info (seed = 607): 291, 0, 4751
# Last time info (seed = 608): 365, 0, 4677
# Last time info (seed = 609): 296, 0, 4746
# Last time info (seed = 610): 321, 0, 4721
# Last time info (seed = 611): 285, 0, 4757
# Last time info (seed = 612): 340, 0, 4702
# Last time info (seed = 613): 317, 0, 4725
# Last time info (seed = 614): 342, 0, 4700
# Last time info (seed = 615): 346, 0, 4696
# Last time info (seed = 616): 352, 0, 4690
# Last time info (seed = 617): 312, 0, 4730
# Last time info (seed = 618): 308, 0, 4734
# Last time info (seed = 619): 324, 0, 4718
# Last time info (seed = 620): 305, 0, 4737
# Last time info (seed = 621): 286, 0, 4756
# Last time info (seed = 622): 294, 0, 4748
# Last time info (seed = 623): 346, 0, 4696
# Last time info (seed = 624): 308, 0, 4734
# Last time info (seed = 625): 289, 0, 4753
# Last time info (seed = 626): 365, 0, 4677
# Last time info (seed = 627): 318, 0, 4724
# Last time info (seed = 628): 340, 0, 4702
# Last time info (seed = 629): 290, 0, 4752
# Last time info (seed = 630): 294, 0, 4748
# Last time info (seed = 631): 295, 0, 4747
# Last time info (seed = 632): 354, 0, 4688
# Last time info (seed = 633): 361, 0, 4681
# Last time info (seed = 634): 342, 0, 4700
# Last time info (seed = 635): 286, 0, 4756
# Last time info (seed = 636): 5041, 0, 1
# Last time info (seed = 637): 335, 0, 4707
# Last time info (seed = 638): 307, 0, 4735
# Last time info (seed = 639): 353, 0, 4689
# Last time info (seed = 640): 305, 0, 4737
# Last time info (seed = 641): 305, 0, 4737
# Last time info (seed = 642): 350, 0, 4692
# Last time info (seed = 643): 320, 0, 4722
# Last time info (seed = 644): 335, 0, 4707
# Last time info (seed = 645): 366, 0, 4676
# Last time info (seed = 646): 300, 0, 4742
# Last time info (seed = 647): 356, 0, 4686
# Last time info (seed = 648): 397, 0, 4645
# Last time info (seed = 649): 316, 0, 4726
# Last time info (seed = 650): 326, 0, 4716
# Last time info (seed = 651): 338, 0, 4704
# Last time info (seed = 652): 290, 0, 4752
# Last time info (seed = 653): 317, 0, 4725
# Last time info (seed = 654): 326, 0, 4716
# Last time info (seed = 655): 419, 0, 4623
# Last time info (seed = 656): 293, 0, 4749
# Last time info (seed = 657): 5041, 0, 1
# Last time info (seed = 658): 335, 0, 4707
# Last time info (seed = 659): 309, 0, 4733
# Last time info (seed = 660): 331, 0, 4711
# Last time info (seed = 661): 315, 0, 4727
# Last time info (seed = 662): 420, 0, 4622
# Last time info (seed = 663): 290, 0, 4752
# Last time info (seed = 664): 306, 0, 4736
# Last time info (seed = 665): 354, 0, 4688
# Last time info (seed = 666): 261, 0, 4781
# Last time info (seed = 667): 333, 0, 4709
# Last time info (seed = 668): 356, 0, 4686
# Last time info (seed = 669): 307, 0, 4735
# Last time info (seed = 670): 307, 0, 4735
# Last time info (seed = 671): 302, 0, 4740
# Last time info (seed = 672): 256, 0, 4786
# Last time info (seed = 673): 308, 0, 4734
# Last time info (seed = 674): 362, 0, 4680
# Last time info (seed = 675): 310, 0, 4732
# Last time info (seed = 676): 360, 0, 4682
# Last time info (seed = 677): 351, 0, 4691
# Last time info (seed = 678): 365, 0, 4677
# Last time info (seed = 679): 395, 0, 4647
# Last time info (seed = 680): 337, 0, 4705
# Last time info (seed = 681): 356, 0, 4686
# Last time info (seed = 682): 341, 0, 4701
# Last time info (seed = 683): 317, 0, 4725
# Last time info (seed = 684): 340, 0, 4702
# Last time info (seed = 685): 5041, 0, 1
# Last time info (seed = 686): 315, 0, 4727
# Last time info (seed = 687): 378, 0, 4664
# Last time info (seed = 688): 371, 0, 4671
# Last time info (seed = 689): 299, 0, 4743
# Last time info (seed = 690): 385, 0, 4657
# Last time info (seed = 691): 317, 0, 4725
# Last time info (seed = 692): 351, 0, 4691
# Last time info (seed = 693): 301, 0, 4741
# Last time info (seed = 694): 338, 0, 4704
# Last time info (seed = 695): 365, 0, 4677
# Last time info (seed = 696): 323, 0, 4719
# Last time info (seed = 697): 378, 0, 4664
# Last time info (seed = 698): 378, 0, 4664
# Last time info (seed = 699): 306, 0, 4736
# Last time info (seed = 700): 5041, 0, 1
# Last time info (seed = 701): 333, 0, 4709
# Last time info (seed = 702): 307, 0, 4735
# Last time info (seed = 703): 369, 0, 4673
# Last time info (seed = 704): 322, 0, 4720
# Last time info (seed = 705): 319, 0, 4723
# Last time info (seed = 706): 305, 0, 4737
# Last time info (seed = 707): 424, 0, 4618
# Last time info (seed = 708): 329, 0, 4713
# Last time info (seed = 709): 333, 0, 4709
# Last time info (seed = 710): 332, 0, 4710
# Last time info (seed = 711): 318, 0, 4724
# Last time info (seed = 712): 307, 0, 4735
# Last time info (seed = 713): 367, 0, 4675
# Last time info (seed = 714): 5041, 0, 1
# Last time info (seed = 715): 317, 0, 4725
# Last time info (seed = 716): 331, 0, 4711
# Last time info (seed = 717): 269, 0, 4773
# Last time info (seed = 718): 356, 0, 4686
# Last time info (seed = 719): 342, 0, 4700
# Last time info (seed = 720): 304, 0, 4738
# Last time info (seed = 721): 299, 0, 4743
# Last time info (seed = 722): 363, 0, 4679
# Last time info (seed = 723): 302, 0, 4740
# Last time info (seed = 724): 333, 0, 4709
# Last time info (seed = 725): 309, 0, 4733
# Last time info (seed = 726): 266, 0, 4776
# Last time info (seed = 727): 324, 0, 4718
# Last time info (seed = 728): 311, 0, 4731
# Last time info (seed = 729): 347, 0, 4695
# Last time info (seed = 730): 284, 0, 4758
# Last time info (seed = 731): 322, 0, 4720
# Last time info (seed = 732): 306, 0, 4736
# Last time info (seed = 733): 372, 0, 4670
# Last time info (seed = 734): 417, 0, 4625
# Last time info (seed = 735): 381, 0, 4661
# Last time info (seed = 736): 353, 0, 4689
# Last time info (seed = 737): 344, 0, 4698
# Last time info (seed = 738): 288, 0, 4754
# Last time info (seed = 739): 261, 0, 4781
# Last time info (seed = 740): 363, 0, 4679
# Last time info (seed = 741): 350, 0, 4692
# Last time info (seed = 742): 310, 0, 4732
# Last time info (seed = 743): 388, 0, 4654
# Last time info (seed = 744): 288, 0, 4754
# Last time info (seed = 745): 334, 0, 4708
# Last time info (seed = 746): 333, 0, 4709
# Last time info (seed = 747): 312, 0, 4730
# Last time info (seed = 748): 293, 0, 4749
# Last time info (seed = 749): 273, 0, 4769
# Last time info (seed = 750): 282, 0, 4760
# Last time info (seed = 751): 339, 0, 4703
# Last time info (seed = 752): 333, 0, 4709
# Last time info (seed = 753): 291, 0, 4751
# Last time info (seed = 754): 297, 0, 4745
# Last time info (seed = 755): 347, 0, 4695
# Last time info (seed = 756): 361, 0, 4681
# Last time info (seed = 757): 359, 0, 4683
# Last time info (seed = 758): 328, 0, 4714
# Last time info (seed = 759): 345, 0, 4697
# Last time info (seed = 760): 328, 0, 4714
# Last time info (seed = 761): 344, 0, 4698
# Last time info (seed = 762): 336, 0, 4706
# Last time info (seed = 763): 333, 0, 4709
# Last time info (seed = 764): 314, 0, 4728
# Last time info (seed = 765): 306, 0, 4736
# Last time info (seed = 766): 306, 0, 4736
# Last time info (seed = 767): 270, 0, 4772
# Last time info (seed = 768): 344, 0, 4698
# Last time info (seed = 769): 304, 0, 4738
# Last time info (seed = 770): 349, 0, 4693
# Last time info (seed = 771): 378, 0, 4664
# Last time info (seed = 772): 387, 0, 4655
# Last time info (seed = 773): 335, 0, 4707
# Last time info (seed = 774): 421, 0, 4621
# Last time info (seed = 775): 331, 0, 4711
# Last time info (seed = 776): 287, 0, 4755
# Last time info (seed = 777): 271, 0, 4771
# Last time info (seed = 778): 313, 0, 4729
# Last time info (seed = 779): 341, 0, 4701
# Last time info (seed = 780): 364, 0, 4678
# Last time info (seed = 781): 304, 0, 4738
# Last time info (seed = 782): 280, 0, 4762
# Last time info (seed = 783): 342, 0, 4700
# Last time info (seed = 784): 5041, 0, 1
# Last time info (seed = 785): 5041, 0, 1
# Last time info (seed = 786): 333, 0, 4709
# Last time info (seed = 787): 331, 0, 4711
# Last time info (seed = 788): 348, 0, 4694
# Last time info (seed = 789): 306, 0, 4736
# Last time info (seed = 790): 303, 0, 4739
# Last time info (seed = 791): 323, 0, 4719
# Last time info (seed = 792): 349, 0, 4693
# Last time info (seed = 793): 324, 0, 4718
# Last time info (seed = 794): 306, 0, 4736
# Last time info (seed = 795): 5041, 0, 1
# Last time info (seed = 796): 294, 0, 4748
# Last time info (seed = 797): 303, 0, 4739
# Last time info (seed = 798): 346, 0, 4696
# Last time info (seed = 799): 313, 0, 4729
# Last time info (seed = 800): 353, 0, 4689
# Last time info (seed = 801): 330, 0, 4712
# Last time info (seed = 802): 315, 0, 4727
# Last time info (seed = 803): 329, 0, 4713
# Last time info (seed = 804): 378, 0, 4664
# Last time info (seed = 805): 371, 0, 4671
# Last time info (seed = 806): 318, 0, 4724
# Last time info (seed = 807): 340, 0, 4702
# Last time info (seed = 808): 396, 0, 4646
# Last time info (seed = 809): 337, 0, 4705
# Last time info (seed = 810): 285, 0, 4757
# Last time info (seed = 811): 5041, 0, 1
# Last time info (seed = 812): 393, 0, 4649
# Last time info (seed = 813): 330, 0, 4712
# Last time info (seed = 814): 334, 0, 4708
# Last time info (seed = 815): 315, 0, 4727
# Last time info (seed = 816): 336, 0, 4706
# Last time info (seed = 817): 327, 0, 4715
# Last time info (seed = 818): 5040, 0, 2
# Last time info (seed = 819): 400, 0, 4642
# Last time info (seed = 820): 359, 0, 4683
# Last time info (seed = 821): 360, 0, 4682
# Last time info (seed = 822): 314, 0, 4728
# Last time info (seed = 823): 323, 0, 4719
# Last time info (seed = 824): 352, 0, 4690
# Last time info (seed = 825): 332, 0, 4710
# Last time info (seed = 826): 282, 0, 4760
# Last time info (seed = 827): 298, 0, 4744
# Last time info (seed = 828): 335, 0, 4707
# Last time info (seed = 829): 323, 0, 4719
# Last time info (seed = 830): 314, 0, 4728
# Last time info (seed = 831): 323, 0, 4719
# Last time info (seed = 832): 349, 0, 4693
# Last time info (seed = 833): 377, 0, 4665
# Last time info (seed = 834): 295, 0, 4747
# Last time info (seed = 835): 370, 0, 4672
# Last time info (seed = 836): 388, 0, 4654
# Last time info (seed = 837): 380, 0, 4662
# Last time info (seed = 838): 346, 0, 4696
# Last time info (seed = 839): 402, 0, 4640
# Last time info (seed = 840): 297, 0, 4745
# Last time info (seed = 841): 359, 0, 4683
# Last time info (seed = 842): 391, 0, 4651
# Last time info (seed = 843): 301, 0, 4741
# Last time info (seed = 844): 289, 0, 4753
# Last time info (seed = 845): 299, 0, 4743
# Last time info (seed = 846): 324, 0, 4718
# Last time info (seed = 847): 345, 0, 4697
# Last time info (seed = 848): 384, 0, 4658
# Last time info (seed = 849): 287, 0, 4755
# Last time info (seed = 850): 323, 0, 4719
# Last time info (seed = 851): 337, 0, 4705
# Last time info (seed = 852): 372, 0, 4670
# Last time info (seed = 853): 320, 0, 4722
# Last time info (seed = 854): 325, 0, 4717
# Last time info (seed = 855): 412, 0, 4630
# Last time info (seed = 856): 323, 0, 4719
# Last time info (seed = 857): 303, 0, 4739
# Last time info (seed = 858): 313, 0, 4729
# Last time info (seed = 859): 310, 0, 4732
# Last time info (seed = 860): 336, 0, 4706
# Last time info (seed = 861): 337, 0, 4705
# Last time info (seed = 862): 301, 0, 4741
# Last time info (seed = 863): 290, 0, 4752
# Last time info (seed = 864): 314, 0, 4728
# Last time info (seed = 865): 294, 0, 4748
# Last time info (seed = 866): 289, 0, 4753
# Last time info (seed = 867): 280, 0, 4762
# Last time info (seed = 868): 300, 0, 4742
# Last time info (seed = 869): 394, 0, 4648
# Last time info (seed = 870): 271, 0, 4771
# Last time info (seed = 871): 351, 0, 4691
# Last time info (seed = 872): 397, 0, 4645
# Last time info (seed = 873): 5041, 0, 1
# Last time info (seed = 874): 412, 0, 4630
# Last time info (seed = 875): 291, 0, 4751
# Last time info (seed = 876): 296, 0, 4746
# Last time info (seed = 877): 333, 0, 4709
# Last time info (seed = 878): 328, 0, 4714
# Last time info (seed = 879): 347, 0, 4695
# Last time info (seed = 880): 349, 0, 4693
# Last time info (seed = 881): 339, 0, 4703
# Last time info (seed = 882): 310, 0, 4732
# Last time info (seed = 883): 289, 0, 4753
# Last time info (seed = 884): 345, 0, 4697
# Last time info (seed = 885): 303, 0, 4739
# Last time info (seed = 886): 363, 0, 4679
# Last time info (seed = 887): 349, 0, 4693
# Last time info (seed = 888): 337, 0, 4705
# Last time info (seed = 889): 337, 0, 4705
# Last time info (seed = 890): 348, 0, 4694
# Last time info (seed = 891): 299, 0, 4743
# Last time info (seed = 892): 310, 0, 4732
# Last time info (seed = 893): 400, 0, 4642
# Last time info (seed = 894): 313, 0, 4729
# Last time info (seed = 895): 317, 0, 4725
# Last time info (seed = 896): 263, 0, 4779
# Last time info (seed = 897): 317, 0, 4725
# Last time info (seed = 898): 334, 0, 4708
# Last time info (seed = 899): 317, 0, 4725
# Last time info (seed = 900): 320, 0, 4722
# Last time info (seed = 901): 320, 0, 4722
# Last time info (seed = 902): 335, 0, 4707
# Last time info (seed = 903): 319, 0, 4723
# Last time info (seed = 904): 291, 0, 4751
# Last time info (seed = 905): 321, 0, 4721
# Last time info (seed = 906): 314, 0, 4728
# Last time info (seed = 907): 330, 0, 4712
# Last time info (seed = 908): 384, 0, 4658
# Last time info (seed = 909): 288, 0, 4754
# Last time info (seed = 910): 279, 0, 4763
# Last time info (seed = 911): 315, 0, 4727
# Last time info (seed = 912): 333, 0, 4709
# Last time info (seed = 913): 339, 0, 4703
# Last time info (seed = 914): 340, 0, 4702
# Last time info (seed = 915): 352, 0, 4690
# Last time info (seed = 916): 334, 0, 4708
# Last time info (seed = 917): 349, 0, 4693
# Last time info (seed = 918): 307, 0, 4735
# Last time info (seed = 919): 355, 0, 4687
# Last time info (seed = 920): 308, 0, 4734
# Last time info (seed = 921): 255, 0, 4787
# Last time info (seed = 922): 346, 0, 4696
# Last time info (seed = 923): 293, 0, 4749
# Last time info (seed = 924): 367, 0, 4675
# Last time info (seed = 925): 395, 0, 4647
# Last time info (seed = 926): 298, 0, 4744
# Last time info (seed = 927): 298, 0, 4744
# Last time info (seed = 928): 285, 0, 4757
# Last time info (seed = 929): 297, 0, 4745
# Last time info (seed = 930): 331, 0, 4711
# Last time info (seed = 931): 278, 0, 4764
# Last time info (seed = 932): 275, 0, 4767
# Last time info (seed = 933): 298, 0, 4744
# Last time info (seed = 934): 305, 0, 4737
# Last time info (seed = 935): 294, 0, 4748
# Last time info (seed = 936): 284, 0, 4758
# Last time info (seed = 937): 357, 0, 4685
# Last time info (seed = 938): 337, 0, 4705
# Last time info (seed = 939): 337, 0, 4705
# Last time info (seed = 940): 453, 0, 4589
# Last time info (seed = 941): 305, 0, 4737
# Last time info (seed = 942): 356, 0, 4686
# Last time info (seed = 943): 356, 0, 4686
# Last time info (seed = 944): 299, 0, 4743
# Last time info (seed = 945): 344, 0, 4698
# Last time info (seed = 946): 408, 0, 4634
# Last time info (seed = 947): 339, 0, 4703
# Last time info (seed = 948): 292, 0, 4750
# Last time info (seed = 949): 325, 0, 4717
# Last time info (seed = 950): 406, 0, 4636
# Last time info (seed = 951): 328, 0, 4714
# Last time info (seed = 952): 325, 0, 4717
# Last time info (seed = 953): 5040, 0, 2
# Last time info (seed = 954): 363, 0, 4679
# Last time info (seed = 955): 384, 0, 4658
# Last time info (seed = 956): 332, 0, 4710
# Last time info (seed = 957): 338, 0, 4704
# Last time info (seed = 958): 300, 0, 4742
# Last time info (seed = 959): 360, 0, 4682
# Last time info (seed = 960): 312, 0, 4730
# Last time info (seed = 961): 313, 0, 4729
# Last time info (seed = 962): 305, 0, 4737
# Last time info (seed = 963): 319, 0, 4723
# Last time info (seed = 964): 329, 0, 4713
# Last time info (seed = 965): 329, 0, 4713
# Last time info (seed = 966): 306, 0, 4736
# Last time info (seed = 967): 283, 0, 4759
# Last time info (seed = 968): 312, 0, 4730
# Last time info (seed = 969): 334, 0, 4708
# Last time info (seed = 970): 320, 0, 4722
# Last time info (seed = 971): 294, 0, 4748
# Last time info (seed = 972): 332, 0, 4710
# Last time info (seed = 973): 337, 0, 4705
# Last time info (seed = 974): 405, 0, 4637
# Last time info (seed = 975): 341, 0, 4701
# Last time info (seed = 976): 355, 0, 4687
# Last time info (seed = 977): 312, 0, 4730
# Last time info (seed = 978): 347, 0, 4695
# Last time info (seed = 979): 419, 0, 4623
# Last time info (seed = 980): 270, 0, 4772
# Last time info (seed = 981): 303, 0, 4739
# Last time info (seed = 982): 337, 0, 4705
# Last time info (seed = 983): 362, 0, 4680
# Last time info (seed = 984): 302, 0, 4740
# Last time info (seed = 985): 351, 0, 4691
# Last time info (seed = 986): 5041, 0, 1
# Last time info (seed = 987): 273, 0, 4769
# Last time info (seed = 988): 329, 0, 4713
# Last time info (seed = 989): 391, 0, 4651
# Last time info (seed = 990): 250, 0, 4792
# Last time info (seed = 991): 261, 0, 4781
# Last time info (seed = 992): 322, 0, 4720
# Last time info (seed = 993): 267, 0, 4775
# Last time info (seed = 994): 285, 0, 4757
# Last time info (seed = 995): 260, 0, 4782
# Last time info (seed = 996): 314, 0, 4728
# Last time info (seed = 997): 348, 0, 4694
# Last time info (seed = 998): 330, 0, 4712
# Last time info (seed = 999): 327, 0, 4715
# Last time info (seed = 1000): 333, 0, 4709
# Last time info (seed = 1001): 328, 0, 4714
# Last time info (seed = 1002): 318, 0, 4724
# Last time info (seed = 1003): 315, 0, 4727
# Last time info (seed = 1004): 341, 0, 4701
# Last time info (seed = 1005): 292, 0, 4750
# Last time info (seed = 1006): 321, 0, 4721
# Last time info (seed = 1007): 326, 0, 4716
# Last time info (seed = 1008): 359, 0, 4683
# Last time info (seed = 1009): 304, 0, 4738
# Last time info (seed = 1010): 369, 0, 4673
# Last time info (seed = 1011): 304, 0, 4738
# Last time info (seed = 1012): 371, 0, 4671
# Last time info (seed = 1013): 320, 0, 4722
# Last time info (seed = 1014): 241, 0, 4801
# Last time info (seed = 1015): 292, 0, 4750
# Last time info (seed = 1016): 280, 0, 4762
# Last time info (seed = 1017): 338, 0, 4704
# Last time info (seed = 1018): 363, 0, 4679
# Last time info (seed = 1019): 348, 0, 4694
# Last time info (seed = 1020): 314, 0, 4728
# Last time info (seed = 1021): 362, 0, 4680
# Last time info (seed = 1022): 379, 0, 4663
# Last time info (seed = 1023): 342, 0, 4700
# Last time info (seed = 1024): 307, 0, 4735
# Last time info (seed = 1025): 350, 0, 4692
# Last time info (seed = 1026): 323, 0, 4719
# Last time info (seed = 1027): 5041, 0, 1
# Last time info (seed = 1028): 323, 0, 4719
# Last time info (seed = 1029): 378, 0, 4664
# Last time info (seed = 1030): 322, 0, 4720
# Last time info (seed = 1031): 314, 0, 4728
# Last time info (seed = 1032): 358, 0, 4684
# Last time info (seed = 1033): 273, 0, 4769
# Last time info (seed = 1034): 307, 0, 4735
# Last time info (seed = 1035): 5041, 0, 1
# Last time info (seed = 1036): 321, 0, 4721
# Last time info (seed = 1037): 361, 0, 4681
# Last time info (seed = 1038): 294, 0, 4748
# Last time info (seed = 1039): 309, 0, 4733
# Last time info (seed = 1040): 314, 0, 4728
# Last time info (seed = 1041): 351, 0, 4691
# Last time info (seed = 1042): 380, 0, 4662
# Last time info (seed = 1043): 340, 0, 4702
# Last time info (seed = 1044): 393, 0, 4649
# Last time info (seed = 1045): 313, 0, 4729
# Last time info (seed = 1046): 297, 0, 4745
# Last time info (seed = 1047): 397, 0, 4645
# Last time info (seed = 1048): 289, 0, 4753
# Last time info (seed = 1049): 270, 0, 4772
# Last time info (seed = 1050): 318, 0, 4724
# Last time info (seed = 1051): 5041, 0, 1
# Last time info (seed = 1052): 384, 0, 4658
# Last time info (seed = 1053): 350, 0, 4692
# Last time info (seed = 1054): 319, 0, 4723
# Last time info (seed = 1055): 365, 0, 4677
# Last time info (seed = 1056): 361, 0, 4681
# Last time info (seed = 1057): 386, 0, 4656
# Last time info (seed = 1058): 332, 0, 4710
# Last time info (seed = 1059): 300, 0, 4742
# Last time info (seed = 1060): 297, 0, 4745
# Last time info (seed = 1061): 237, 0, 4805
# Last time info (seed = 1062): 339, 0, 4703
# Last time info (seed = 1063): 283, 0, 4759
# Last time info (seed = 1064): 332, 0, 4710
# Last time info (seed = 1065): 316, 0, 4726
# Last time info (seed = 1066): 5041, 0, 1
# Last time info (seed = 1067): 360, 0, 4682
# Last time info (seed = 1068): 5041, 0, 1
# Last time info (seed = 1069): 348, 0, 4694
# Last time info (seed = 1070): 381, 0, 4661
# Last time info (seed = 1071): 408, 0, 4634
# Last time info (seed = 1072): 319, 0, 4723
# Last time info (seed = 1073): 298, 0, 4744
# Last time info (seed = 1074): 295, 0, 4747
# Last time info (seed = 1075): 330, 0, 4712
# Last time info (seed = 1076): 294, 0, 4748
# Last time info (seed = 1077): 385, 0, 4657
# Last time info (seed = 1078): 308, 0, 4734
# Last time info (seed = 1079): 293, 0, 4749
# Last time info (seed = 1080): 342, 0, 4700
# Last time info (seed = 1081): 343, 0, 4699
# Last time info (seed = 1082): 313, 0, 4729
# Last time info (seed = 1083): 322, 0, 4720
# Last time info (seed = 1084): 5041, 0, 1
# Last time info (seed = 1085): 305, 0, 4737
# Last time info (seed = 1086): 378, 0, 4664
# Last time info (seed = 1087): 329, 0, 4713
# Last time info (seed = 1088): 339, 0, 4703
# Last time info (seed = 1089): 298, 0, 4744
# Last time info (seed = 1090): 293, 0, 4749
# Last time info (seed = 1091): 305, 0, 4737
# Last time info (seed = 1092): 333, 0, 4709
# Last time info (seed = 1093): 309, 0, 4733
# Last time info (seed = 1094): 317, 0, 4725
# Last time info (seed = 1095): 330, 0, 4712
# Last time info (seed = 1096): 300, 0, 4742
# Last time info (seed = 1097): 314, 0, 4728
# Last time info (seed = 1098): 337, 0, 4705
# Last time info (seed = 1099): 271, 0, 4771
# Last time info (seed = 1100): 377, 0, 4665
# Last time info (seed = 1101): 343, 0, 4699
# Last time info (seed = 1102): 349, 0, 4693
# Last time info (seed = 1103): 389, 0, 4653
# Last time info (seed = 1104): 295, 0, 4747
# Last time info (seed = 1105): 386, 0, 4656
# Last time info (seed = 1106): 332, 0, 4710
# Last time info (seed = 1107): 265, 0, 4777
# Last time info (seed = 1108): 370, 0, 4672
# Last time info (seed = 1109): 303, 0, 4739
# Last time info (seed = 1110): 362, 0, 4680
# Last time info (seed = 1111): 365, 0, 4677
# Last time info (seed = 1112): 348, 0, 4694
# Last time info (seed = 1113): 293, 0, 4749
# Last time info (seed = 1114): 366, 0, 4676
# Last time info (seed = 1115): 290, 0, 4752
# Last time info (seed = 1116): 334, 0, 4708
# Last time info (seed = 1117): 327, 0, 4715
# Last time info (seed = 1118): 299, 0, 4743
# Last time info (seed = 1119): 271, 0, 4771
# Last time info (seed = 1120): 5041, 0, 1
# Last time info (seed = 1121): 373, 0, 4669
# Last time info (seed = 1122): 326, 0, 4716
# Last time info (seed = 1123): 332, 0, 4710
# Last time info (seed = 1124): 299, 0, 4743
# Last time info (seed = 1125): 5041, 0, 1
# Last time info (seed = 1126): 369, 0, 4673
# Last time info (seed = 1127): 365, 0, 4677
# Last time info (seed = 1128): 348, 0, 4694
# Last time info (seed = 1129): 363, 0, 4679
# Last time info (seed = 1130): 291, 0, 4751
# Last time info (seed = 1131): 304, 0, 4738
# Last time info (seed = 1132): 330, 0, 4712
# Last time info (seed = 1133): 302, 0, 4740
# Last time info (seed = 1134): 321, 0, 4721
# Last time info (seed = 1135): 335, 0, 4707
# Last time info (seed = 1136): 350, 0, 4692
# Last time info (seed = 1137): 293, 0, 4749
# Last time info (seed = 1138): 329, 0, 4713
# Last time info (seed = 1139): 332, 0, 4710
# Last time info (seed = 1140): 343, 0, 4699
# Last time info (seed = 1141): 295, 0, 4747
# Last time info (seed = 1142): 292, 0, 4750
# Last time info (seed = 1143): 388, 0, 4654
# ...
# Last time info (seed = 4667): 5041, 0, 1
# Last time info (seed = 4668): 5041, 0, 1
# Last time info (seed = 4669): 285, 0, 4757
# Last time info (seed = 4670): 5041, 0, 1
# Last time info (seed = 4671): 315, 0, 4727
# Last time info (seed = 4672): 297, 0, 4745
# Last time info (seed = 4673): 267, 0, 4775
# Last time info (seed = 4674): 328, 0, 4714
# Last time info (seed = 4675): 400, 0, 4642
# Last time info (seed = 4676): 5041, 0, 1
# Last time info (seed = 4677): 348, 0, 4694
# Last time info (seed = 4678): 298, 0, 4744
# Last time info (seed = 4679): 338, 0, 4704
# Last time info (seed = 4680): 5041, 0, 1
# Last time info (seed = 4681): 360, 0, 4682
# Last time info (seed = 4682): 306, 0, 4736
# Last time info (seed = 4683): 336, 0, 4706
# Last time info (seed = 4684): 289, 0, 4753
# Last time info (seed = 4685): 386, 0, 4656
# Last time info (seed = 4686): 307, 0, 4735
# Last time info (seed = 4687): 353, 0, 4689
# Last time info (seed = 4688): 240, 0, 4802
# Last time info (seed = 4689): 5041, 0, 1
# Last time info (seed = 4690): 5041, 0, 1
# Last time info (seed = 4691): 312, 0, 4730
# Last time info (seed = 4692): 348, 0, 4694
# Last time info (seed = 4693): 312, 0, 4730
# Last time info (seed = 4694): 318, 0, 4724
# Last time info (seed = 4695): 362, 0, 4680
# Last time info (seed = 4696): 324, 0, 4718
# Last time info (seed = 4697): 316, 0, 4726
# Last time info (seed = 4698): 263, 0, 4779
# Last time info (seed = 4699): 335, 0, 4707
# Last time info (seed = 4700): 374, 0, 4668
# Last time info (seed = 4701): 342, 0, 4700
# Last time info (seed = 4702): 409, 0, 4633
# Last time info (seed = 4703): 315, 0, 4727
# Last time info (seed = 4704): 5041, 0, 1
# Last time info (seed = 4705): 417, 0, 4625
# Last time info (seed = 4706): 352, 0, 4690
# Last time info (seed = 4707): 290, 0, 4752
# Last time info (seed = 4708): 285, 0, 4757
# Last time info (seed = 4709): 345, 0, 4697
# Last time info (seed = 4710): 5039, 0, 3
# Last time info (seed = 4711): 296, 0, 4746
# Last time info (seed = 4712): 394, 0, 4648
# Last time info (seed = 4713): 302, 0, 4740
# Last time info (seed = 4714): 339, 0, 4703
# Last time info (seed = 4715): 330, 0, 4712
# Last time info (seed = 4716): 5041, 0, 1
# Last time info (seed = 4717): 5041, 0, 1
# Last time info (seed = 4718): 5041, 0, 1
# Last time info (seed = 4719): 288, 0, 4754
# Last time info (seed = 4720): 385, 0, 4657
# Last time info (seed = 4721): 328, 0, 4714
# Last time info (seed = 4722): 296, 0, 4746
# Last time info (seed = 4723): 289, 0, 4753
# Last time info (seed = 4724): 279, 0, 4763
# Last time info (seed = 4725): 290, 0, 4752
# Last time info (seed = 4726): 344, 0, 4698
# Last time info (seed = 4727): 356, 0, 4686
# Last time info (seed = 4728): 343, 0, 4699
# Last time info (seed = 4729): 5041, 0, 1
# Last time info (seed = 4730): 306, 0, 4736
# Last time info (seed = 4731): 338, 0, 4704
# Last time info (seed = 4732): 341, 0, 4701
# Last time info (seed = 4733): 254, 0, 4788
# Last time info (seed = 4734): 265, 0, 4777
# Last time info (seed = 4735): 310, 0, 4732
# Last time info (seed = 4736): 328, 0, 4714
# Last time info (seed = 4737): 379, 0, 4663
# Last time info (seed = 4738): 316, 0, 4726
# Last time info (seed = 4739): 312, 0, 4730
# Last time info (seed = 4740): 334, 0, 4708
# Last time info (seed = 4741): 270, 0, 4772
# Last time info (seed = 4742): 303, 0, 4739
# Last time info (seed = 4743): 305, 0, 4737
# Last time info (seed = 4744): 5041, 0, 1
# Last time info (seed = 4745): 329, 0, 4713
# Last time info (seed = 4746): 353, 0, 4689
# Last time info (seed = 4747): 293, 0, 4749
# Last time info (seed = 4748): 5041, 0, 1
# Last time info (seed = 4749): 341, 0, 4701
# Last time info (seed = 4750): 5041, 0, 1
# Last time info (seed = 4751): 277, 0, 4765
# Last time info (seed = 4752): 290, 0, 4752
# Last time info (seed = 4753): 347, 0, 4695
# Last time info (seed = 4754): 5041, 0, 1
# Last time info (seed = 4755): 5041, 0, 1
# Last time info (seed = 4756): 380, 0, 4662
# Last time info (seed = 4757): 253, 0, 4789
# Last time info (seed = 4758): 337, 0, 4705
# Last time info (seed = 4759): 368, 0, 4674
# Last time info (seed = 4760): 300, 0, 4742
# Last time info (seed = 4761): 280, 0, 4762
# Last time info (seed = 4762): 5041, 0, 1
# Last time info (seed = 4763): 310, 0, 4732
# Last time info (seed = 4764): 5041, 0, 1
# Last time info (seed = 4765): 323, 0, 4719
# Last time info (seed = 4766): 5041, 0, 1
# Last time info (seed = 4767): 314, 0, 4728
# Last time info (seed = 4768): 313, 0, 4729
# Last time info (seed = 4769): 312, 0, 4730
# Last time info (seed = 4770): 331, 0, 4711
# Last time info (seed = 4771): 5041, 0, 1
# Last time info (seed = 4772): 5041, 0, 1
# Last time info (seed = 4773): 294, 0, 4748
# Last time info (seed = 4774): 364, 0, 4678
# Last time info (seed = 4775): 354, 0, 4688
# Last time info (seed = 4776): 5041, 0, 1
# Last time info (seed = 4777): 359, 0, 4683
# Last time info (seed = 4778): 373, 0, 4669
# Last time info (seed = 4779): 336, 0, 4706
# Last time info (seed = 4780): 336, 0, 4706
# Last time info (seed = 4781): 316, 0, 4726
# Last time info (seed = 4782): 363, 0, 4679
# Last time info (seed = 4783): 306, 0, 4736
# Last time info (seed = 4784): 313, 0, 4729
# Last time info (seed = 4785): 306, 0, 4736
# Last time info (seed = 4786): 381, 0, 4661
# Last time info (seed = 4787): 361, 0, 4681
# Last time info (seed = 4788): 313, 0, 4729
# Last time info (seed = 4789): 360, 0, 4682
# Last time info (seed = 4790): 5040, 0, 2
# Last time info (seed = 4791): 257, 0, 4785
# Last time info (seed = 4792): 405, 0, 4637
# Last time info (seed = 4793): 5041, 0, 1
# Last time info (seed = 4794): 351, 0, 4691
# Last time info (seed = 4795): 5041, 0, 1
# Last time info (seed = 4796): 353, 0, 4689
# Last time info (seed = 4797): 344, 0, 4698
# Last time info (seed = 4798): 337, 0, 4705
# Last time info (seed = 4799): 315, 0, 4727
# Last time info (seed = 4800): 292, 0, 4750
# Last time info (seed = 4801): 5041, 0, 1
# Last time info (seed = 4802): 5040, 0, 2
# Last time info (seed = 4803): 307, 0, 4735
# Last time info (seed = 4804): 307, 0, 4735
# Last time info (seed = 4805): 295, 0, 4747
# Last time info (seed = 4806): 277, 0, 4765
# Last time info (seed = 4807): 336, 0, 4706
# Last time info (seed = 4808): 5041, 0, 1
# Last time info (seed = 4809): 355, 0, 4687
# Last time info (seed = 4810): 335, 0, 4707
# Last time info (seed = 4811): 288, 0, 4754
# Last time info (seed = 4812): 328, 0, 4714
# Last time info (seed = 4813): 396, 0, 4646
# Last time info (seed = 4814): 5041, 0, 1
# Last time info (seed = 4815): 314, 0, 4728
# Last time info (seed = 4816): 352, 0, 4690
# Last time info (seed = 4817): 334, 0, 4708
# Last time info (seed = 4818): 328, 0, 4714
# Last time info (seed = 4819): 303, 0, 4739
# Last time info (seed = 4820): 379, 0, 4663
# Last time info (seed = 4821): 361, 0, 4681
# Last time info (seed = 4822): 5041, 0, 1
# Last time info (seed = 4823): 293, 0, 4749
# Last time info (seed = 4824): 362, 0, 4680
# Last time info (seed = 4825): 283, 0, 4759
# Last time info (seed = 4826): 5041, 0, 1
# Last time info (seed = 4827): 287, 0, 4755
# Last time info (seed = 4828): 316, 0, 4726
# Last time info (seed = 4829): 277, 0, 4765
# Last time info (seed = 4830): 387, 0, 4655
# Last time info (seed = 4831): 273, 0, 4769
# Last time info (seed = 4832): 322, 0, 4720
# Last time info (seed = 4833): 5040, 0, 2
# Last time info (seed = 4834): 319, 0, 4723
# Last time info (seed = 4835): 361, 0, 4681
# Last time info (seed = 4836): 384, 0, 4658
# Last time info (seed = 4837): 5041, 0, 1
# Last time info (seed = 4838): 306, 0, 4736
# Last time info (seed = 4839): 365, 0, 4677
# Last time info (seed = 4840): 311, 0, 4731
# Last time info (seed = 4841): 5041, 0, 1
# Last time info (seed = 4842): 5041, 0, 1
# Last time info (seed = 4843): 347, 0, 4695
# Last time info (seed = 4844): 276, 0, 4766
# Last time info (seed = 4845): 277, 0, 4765
# Last time info (seed = 4846): 309, 0, 4733
# Last time info (seed = 4847): 363, 0, 4679
# Last time info (seed = 4848): 282, 0, 4760
# Last time info (seed = 4849): 267, 0, 4775
# Last time info (seed = 4850): 310, 0, 4732
# Last time info (seed = 4851): 333, 0, 4709
# Last time info (seed = 4852): 367, 0, 4675
# Last time info (seed = 4853): 5041, 0, 1
# Last time info (seed = 4854): 282, 0, 4760
# Last time info (seed = 4855): 348, 0, 4694
# Last time info (seed = 4856): 393, 0, 4649
# Last time info (seed = 4857): 5041, 0, 1
# Last time info (seed = 4858): 278, 0, 4764
# Last time info (seed = 4859): 327, 0, 4715
# Last time info (seed = 4860): 338, 0, 4704
# Last time info (seed = 4861): 379, 0, 4663
# Last time info (seed = 4862): 382, 0, 4660
# Last time info (seed = 4863): 333, 0, 4709
# Last time info (seed = 4864): 372, 0, 4670
# Last time info (seed = 4865): 372, 0, 4670
# Last time info (seed = 4866): 313, 0, 4729
# Last time info (seed = 4867): 304, 0, 4738
# Last time info (seed = 4868): 365, 0, 4677
# Last time info (seed = 4869): 333, 0, 4709
# Last time info (seed = 4870): 319, 0, 4723
# Last time info (seed = 4871): 353, 0, 4689
# Last time info (seed = 4872): 345, 0, 4697
# Last time info (seed = 4873): 5041, 0, 1
# Last time info (seed = 4874): 5041, 0, 1
# Last time info (seed = 4875): 327, 0, 4715
# Last time info (seed = 4876): 401, 0, 4641
# Last time info (seed = 4877): 327, 0, 4715
# Last time info (seed = 4878): 321, 0, 4721
# Last time info (seed = 4879): 321, 0, 4721
# Last time info (seed = 4880): 335, 0, 4707
# Last time info (seed = 4881): 344, 0, 4698
# Last time info (seed = 4882): 5041, 0, 1
# Last time info (seed = 4883): 294, 0, 4748
# Last time info (seed = 4884): 345, 0, 4697
# Last time info (seed = 4885): 375, 0, 4667
# Last time info (seed = 4886): 368, 0, 4674
# Last time info (seed = 4887): 303, 0, 4739
# Last time info (seed = 4888): 325, 0, 4717
# Last time info (seed = 4889): 284, 0, 4758
# Last time info (seed = 4890): 244, 0, 4798
# Last time info (seed = 4891): 323, 0, 4719
# Last time info (seed = 4892): 277, 0, 4765
# Last time info (seed = 4893): 314, 0, 4728
# Last time info (seed = 4894): 405, 0, 4637
# Last time info (seed = 4895): 293, 0, 4749
# Last time info (seed = 4896): 299, 0, 4743
# Last time info (seed = 4897): 317, 0, 4725
# Last time info (seed = 4898): 357, 0, 4685
# Last time info (seed = 4899): 299, 0, 4743
# Last time info (seed = 4900): 365, 0, 4677
# Last time info (seed = 4901): 305, 0, 4737
# Last time info (seed = 4902): 320, 0, 4722
# Last time info (seed = 4903): 291, 0, 4751
# Last time info (seed = 4904): 262, 0, 4780
# Last time info (seed = 4905): 337, 0, 4705
# Last time info (seed = 4906): 5041, 0, 1
# Last time info (seed = 4907): 295, 0, 4747
# Last time info (seed = 4908): 393, 0, 4649
# Last time info (seed = 4909): 336, 0, 4706
# Last time info (seed = 4910): 365, 0, 4677
# Last time info (seed = 4911): 5040, 0, 2
# Last time info (seed = 4912): 322, 0, 4720
# Last time info (seed = 4913): 329, 0, 4713
# Last time info (seed = 4914): 283, 0, 4759
# Last time info (seed = 4915): 264, 0, 4778
# Last time info (seed = 4916): 311, 0, 4731
# Last time info (seed = 4917): 305, 0, 4737
# Last time info (seed = 4918): 291, 0, 4751
# Last time info (seed = 4919): 5041, 0, 1
# Last time info (seed = 4920): 323, 0, 4719
# Last time info (seed = 4921): 361, 0, 4681
# Last time info (seed = 4922): 335, 0, 4707
# Last time info (seed = 4923): 339, 0, 4703
# Last time info (seed = 4924): 284, 0, 4758
# Last time info (seed = 4925): 5041, 0, 1
# Last time info (seed = 4926): 286, 0, 4756
# Last time info (seed = 4927): 347, 0, 4695
# Last time info (seed = 4928): 366, 0, 4676
# Last time info (seed = 4929): 5041, 0, 1
# Last time info (seed = 4930): 296, 0, 4746
# Last time info (seed = 4931): 290, 0, 4752
# Last time info (seed = 4932): 423, 0, 4619
# Last time info (seed = 4933): 303, 0, 4739
# Last time info (seed = 4934): 343, 0, 4699
# Last time info (seed = 4935): 5041, 0, 1
# Last time info (seed = 4936): 5041, 0, 1
# Last time info (seed = 4937): 346, 0, 4696
# Last time info (seed = 4938): 5041, 0, 1
# Last time info (seed = 4939): 329, 0, 4713
# Last time info (seed = 4940): 306, 0, 4736
# Last time info (seed = 4941): 351, 0, 4691
# Last time info (seed = 4942): 5041, 0, 1
# Last time info (seed = 4943): 288, 0, 4754
# Last time info (seed = 4944): 349, 0, 4693
# Last time info (seed = 4945): 282, 0, 4760
# Last time info (seed = 4946): 340, 0, 4702
# Last time info (seed = 4947): 339, 0, 4703
# Last time info (seed = 4948): 346, 0, 4696
# Last time info (seed = 4949): 372, 0, 4670
# Last time info (seed = 4950): 285, 0, 4757
# Last time info (seed = 4951): 385, 0, 4657
# Last time info (seed = 4952): 327, 0, 4715
# Last time info (seed = 4953): 315, 0, 4727
# Last time info (seed = 4954): 296, 0, 4746
# Last time info (seed = 4955): 320, 0, 4722
# Last time info (seed = 4956): 359, 0, 4683
# Last time info (seed = 4957): 5041, 0, 1
# Last time info (seed = 4958): 271, 0, 4771
# Last time info (seed = 4959): 5041, 0, 1
# Last time info (seed = 4960): 352, 0, 4690
# Last time info (seed = 4961): 336, 0, 4706
# Last time info (seed = 4962): 288, 0, 4754
# Last time info (seed = 4963): 5041, 0, 1
# Last time info (seed = 4964): 321, 0, 4721
# Last time info (seed = 4965): 5040, 0, 2
# Last time info (seed = 4966): 339, 0, 4703
# Last time info (seed = 4967): 5041, 0, 1
# Last time info (seed = 4968): 289, 0, 4753
# Last time info (seed = 4969): 316, 0, 4726
# Last time info (seed = 4970): 287, 0, 4755
# Last time info (seed = 4971): 324, 0, 4718
# Last time info (seed = 4972): 325, 0, 4717
# Last time info (seed = 4973): 330, 0, 4712
# Last time info (seed = 4974): 398, 0, 4644
# Last time info (seed = 4975): 353, 0, 4689
# Last time info (seed = 4976): 318, 0, 4724
# Last time info (seed = 4977): 5041, 0, 1
# Last time info (seed = 4978): 5040, 0, 2
# Last time info (seed = 4979): 267, 0, 4775
# Last time info (seed = 4980): 348, 0, 4694
# Last time info (seed = 4981): 354, 0, 4688
# Last time info (seed = 4982): 5041, 0, 1
# Last time info (seed = 4983): 331, 0, 4711
# Last time info (seed = 4984): 337, 0, 4705
# Last time info (seed = 4985): 352, 0, 4690
# Last time info (seed = 4986): 5041, 0, 1
# Last time info (seed = 4987): 342, 0, 4700
# Last time info (seed = 4988): 261, 0, 4781
# Last time info (seed = 4989): 364, 0, 4678
# Last time info (seed = 4990): 325, 0, 4717
# Last time info (seed = 4991): 362, 0, 4680
# Last time info (seed = 4992): 343, 0, 4699
# Last time info (seed = 4993): 5041, 0, 1
# Last time info (seed = 4994): 357, 0, 4685
# Last time info (seed = 4995): 317, 0, 4725
# Last time info (seed = 4996): 315, 0, 4727
# Last time info (seed = 4997): 305, 0, 4737
# Last time info (seed = 4998): 255, 0, 4787
# Last time info (seed = 4999): 284, 0, 4758
# Last time info (seed = 5000): 409, 0, 4633
# Last time info (seed = 5001): 319, 0, 4723
# Last time info (seed = 5002): 317, 0, 4725
# Last time info (seed = 5003): 288, 0, 4754
# Last time info (seed = 5004): 304, 0, 4738
# Last time info (seed = 5005): 5041, 0, 1
# Last time info (seed = 5006): 327, 0, 4715
# Last time info (seed = 5007): 328, 0, 4714
# Last time info (seed = 5008): 5041, 0, 1
# Last time info (seed = 5009): 376, 0, 4666
# Last time info (seed = 5010): 344, 0, 4698
# Last time info (seed = 5011): 313, 0, 4729
# Last time info (seed = 5012): 5041, 0, 1
# Last time info (seed = 5013): 5041, 0, 1
# Last time info (seed = 5014): 294, 0, 4748
# Last time info (seed = 5015): 286, 0, 4756
# Last time info (seed = 5016): 5041, 0, 1
# Last time info (seed = 5017): 360, 0, 4682
# Last time info (seed = 5018): 372, 0, 4670
# Last time info (seed = 5019): 343, 0, 4699
# Last time info (seed = 5020): 332, 0, 4710
# Last time info (seed = 5021): 5041, 0, 1
# Last time info (seed = 5022): 332, 0, 4710
# Last time info (seed = 5023): 306, 0, 4736
# Last time info (seed = 5024): 353, 0, 4689
# Last time info (seed = 5025): 5041, 0, 1
# Last time info (seed = 5026): 311, 0, 4731
# Last time info (seed = 5027): 287, 0, 4755
# Last time info (seed = 5028): 263, 0, 4779
# Last time info (seed = 5029): 359, 0, 4683
# Last time info (seed = 5030): 294, 0, 4748
# Last time info (seed = 5031): 352, 0, 4690
# Last time info (seed = 5032): 411, 0, 4631
# Last time info (seed = 5033): 5041, 0, 1
# Last time info (seed = 5034): 310, 0, 4732
# Last time info (seed = 5035): 5041, 0, 1
# Last time info (seed = 5036): 350, 0, 4692
# Last time info (seed = 5037): 313, 0, 4729
# Last time info (seed = 5038): 382, 0, 4660
# Last time info (seed = 5039): 340, 0, 4702
# Last time info (seed = 5040): 5041, 0, 1
# Last time info (seed = 5041): 342, 0, 4700

# %%
deg_corr = stat.correlation(R_rate_list, degree_list)
bet_corr = stat.correlation(R_rate_list, bet_list)
eigen_corr = stat.correlation(R_rate_list, eigen_list)
close_corr = stat.correlation(R_rate_list, close_list)

# %%
print('Comparação entre medidas da rede e fração de recuperados para seed nodes')
print('Grau médio: ', deg_corr)
print('Betweeness: ', bet_corr)
print('Eigenvector ctl.: ', eigen_corr)
print('Closeness: ', close_corr)
# Out:
# Comparação entre medidas da rede e fração de recuperados para seed nodes
# Grau médio:  0.12409879977264314
# Betweeness:  0.13899553216664276
# Eigenvector ctl.:  0.13899553216664276
# Closeness:  0.24315291141714399

# %% [markdown]
# A maior correlação foi encontrada na medida de Closeness Centrality. Pela definição, essa medida indica a proximidade do nó em relação à outros, e portanto, a correlação se mostra bem condizente.

# %% [markdown]
# <hr>

# %% [markdown]
# **5 -** Gere redes do tipo BA, ER e WS (p=0.05) com grau médio igual a 10 e N = 500. Desenvolva um estudo para mostrar que essas apresentam topologias diferentes. (Seja criativ@).

# %% [markdown]
# Disclaimer: como já realizado no trabalho de classificação de redes, poderia ter gerado várias redes e realizado o PCA, porém tentei fazer algo diferente utilizando o que aprendemos ao longo da matéria.

# %% [markdown]
# Primeiro são definidas funções para analisar redes BA, ER e WS.

# %%
import itertools
import collections

def ff3(x):
    return x*(x-1)*(x-2)

def avg_tetr_cc(g):
    tetrahedra = itertools.islice(itertools.groupby(
        nx.enumerate_all_cliques(g), len), 3, 4)
    try:
        tetrahedra = next(tetrahedra)[1]
    except StopIteration:
        return 0
    cnts = collections.Counter(itertools.chain(*tetrahedra))
    return 6 * sum(cnt / ff3(g.degree[v]) for v, cnt in cnts.items()) / len(g)

# %%
def community_layout(g, partition):
    """
    Compute the layout for a modular graph.


    Arguments:
    ----------
    g -- networkx.Graph or networkx.DiGraph instance
        graph to plot

    partition -- dict mapping int node -> int community
        graph partitions


    Returns:
    --------
    pos -- dict mapping int node -> (float x, float y)
        node positions

    """

    pos_communities = _position_communities(g, partition, scale=3.)

    pos_nodes = _position_nodes(g, partition, scale=1.)

    # combine positions
    pos = dict()
    for node in g.nodes():
        pos[node] = pos_communities[node] + pos_nodes[node]

    return pos

def _position_communities(g, partition, **kwargs):

    # create a weighted graph, in which each node corresponds to a community,
    # and each edge weight to the number of edges between communities
    between_community_edges = _find_between_community_edges(g, partition)

    communities = set(partition.values())
    hypergraph = nx.DiGraph()
    hypergraph.add_nodes_from(communities)
    for (ci, cj), edges in between_community_edges.items():
        hypergraph.add_edge(ci, cj, weight=len(edges))

    # find layout for communities
    pos_communities = nx.spring_layout(hypergraph, **kwargs)

    # set node positions to position of community
    pos = dict()
    for node, community in partition.items():
        pos[node] = pos_communities[community]

    return pos

def _find_between_community_edges(g, partition):

    edges = dict()

    for (ni, nj) in g.edges():
        ci = partition[ni]
        cj = partition[nj]

        if ci != cj:
            try:
                edges[(ci, cj)] += [(ni, nj)]
            except KeyError:
                edges[(ci, cj)] = [(ni, nj)]

    return edges

def _position_nodes(g, partition, **kwargs):
    """
    Positions nodes within communities.
    """

    communities = dict()
    for node, community in partition.items():
        try:
            communities[community] += [node]
        except KeyError:
            communities[community] = [node]

    pos = dict()
    for ci, nodes in communities.items():
        subgraph = g.subgraph(nodes)
        pos_subgraph = nx.spring_layout(subgraph, **kwargs)
        pos.update(pos_subgraph)

    return pos

def plot_with_communities(G):
    # to install networkx 2.0 compatible version of python-louvain use:
    # pip install -U git+https://github.com/taynaud/python-louvain.git@networkx2
    from community import community_louvain

    partition = community_louvain.best_partition(G)
    pos = community_layout(G, partition)
    
    d = dict(G.degree)
    
    nx.draw_networkx_nodes(G, pos, node_color=list(partition.values()), 
                           node_size=[1*v for v in d.values()])
    plt.show()
    return

# %%
def plot_attacks(G, attack_type):
  if attack_type != "targeted" and attack_type != "random":
    print("Possible attack types: 'targeted' and 'random'.")
    return

  C = G.copy()
  N = C.number_of_nodes()
  number_of_steps = 25
  M = N // number_of_steps
  random_attack_core_proportions = []
  num_nodes_removed = range(0, N, M)
  for nodes_removed in num_nodes_removed:
      # Measure the relative size of the network core
      core = next(nx.connected_components(C))
      core_proportion = len(core) / N
      random_attack_core_proportions.append(core_proportion)
      
      # If there are more than M nodes, select M nodes at random and remove them
      if C.number_of_nodes() > M:
        if attack_type == "random":
          nodes_to_remove = random.sample(list(C.nodes), M)
          C.remove_nodes_from(nodes_to_remove)
        elif attack_type == "targeted":
          nodes_sorted_by_degree = sorted(C.nodes, key=C.degree, reverse=True)
          nodes_to_remove = nodes_sorted_by_degree[:M]
          C.remove_nodes_from(nodes_to_remove)
  
  plt.title(attack_type)
  plt.xlabel('Number of nodes removed')
  plt.ylabel('Proportion of nodes in core')
  plt.plot(num_nodes_removed, random_attack_core_proportions, marker='o')

# %%
from collections import Counter

class Graph():
  def __init__(self, graph, name):
    self.G = graph
    self.name = name
    self.deg_list = [self.G.degree(n) for n in self.G.nodes()]
    self.nodes = nx.number_of_nodes(self.G)
    self.edges = nx.number_of_edges(self.G)
    self._density = nx.density(self.G)
    self._da_coeff = nx.degree_assortativity_coefficient(self.G)
    if(nx.is_connected(self.G)):
      self._spl_mean = nx.average_shortest_path_length(self.G)
    else:
      closeness_centr = nx.closeness_centrality(self.G)
      self._spl_mean = stat.mean(closeness_centr)
    nodes_clustering = nx.clustering(self.G)
    self._c_mean = stat.mean(nodes_clustering.values())
    self._c_stdev = stat.stdev(nodes_clustering.values())
    self._dg_mean = stat.mean(self.deg_list)
    self._dg_stdev = stat.stdev(self.deg_list)
    self.dg_median = stat.median(self.deg_list)
    betweenness = nx.betweenness_centrality(self.G)
    self.betweenness_sequence = list(betweenness.values())
    self._bt_mean = stat.mean(self.betweenness_sequence)
    self._bt_stdev = stat.stdev(self.betweenness_sequence)
    self._bt_median = stat.median(self.betweenness_sequence)

  def bgm(self):
    print(self.name) 
    print("Nodes:", self.nodes)
    print("Links:", self.edges)
    print("Density:", self._density)

  def swm(self):
    print("Small world measures: ") 
    print("Assortativity by degree:", self._da_coeff)
    print("Average shortest path lenght:", self._spl_mean)

  def plot(self):
    nx.draw(self.G, node_size=2)

  def deg_graph(self):
    k, Pk = degree_distribution(self.G)
    inv_cumsum = 1 - np.cumsum(Pk)
    fig, ax = plt.subplots()
    plt.loglog(k, inv_cumsum, 'o')

    plt.title(f"{self.name} model")
    plt.ylabel("Inverso da cumulativa de $P(k)$")
    plt.xlabel("$k$")
    plt.show()

    
  def centrality(self):
    #centrality distributions
    print("Centrality: ")
    print("Mean degree:", self._dg_mean)
    print("Median degree:", self.dg_median)
    print("Mean betweenness:", self._bt_mean)
    print("Median betweenness:", self._bt_median)
    #plots
    degree_counts = Counter(self.deg_list)
    plt.ylabel("N of nodes")
    plt.xlabel("Betweenness")
    plt.hist(self.betweenness_sequence)
    if(self.name == "Barabasi-Albert"):
        plt.yscale('log')
    plt.grid(True)
    plt.show()
    
  def robustness(self):
    #robustness
    plt.figure(1)
    plot_attacks(self.G, "random")
    plt.figure(2)
    plot_attacks(self.G, "targeted")
    plt.show()
  
  def core(self):
    #tried to simplify the graph with a core decomposition
    plt.figure(3)
    n = nx.number_of_nodes(self.G)
    net = self.G
    k = 1
    nodes_after_dec = n #nodes after decomposition
    while(nodes_after_dec != 0):
      oldNet = net
      net = nx.k_core(net, k)
      k += 1
      nodes_after_dec = nx.number_of_nodes(net)
    pos = nx.spring_layout(oldNet)
    nx.draw_networkx_nodes(oldNet, pos, node_size=20)
    nx.draw_networkx_edges(oldNet, pos, alpha=0.2)
    plt.plot()
    plt.show()
    
    
  def clustering(self):
    print('Clustering: ') 
    print("Clustering coefficient:", self._c_mean)
    print("Clustering standart deviation", self._c_stdev)
    self.avg_tetrahedron_cc = avg_tetr_cc(self.G)
    print("Tetrahedron Clustering: ", self.avg_tetrahedron_cc)

# %%
nodes = 500
k = 10
m = int(k/2)
p = k/(nodes-1)

er_graph = Graph(nx.erdos_renyi_graph(nodes, p), "Erdos-Renyi")
ws_graph = Graph(nx.watts_strogatz_graph(nodes, k, 0.3), "Watts-Strogatz")
ba_graph = Graph(nx.barabasi_albert_graph(nodes, m), "Barabasi-Albert")

# %% [markdown]
# Nas medidas geradas, começamos com uma *decomposição k-core*, que permite visualizar o núcleo de maior grau do gráfico.
#
# Logo em seguida, plotamos um gráfico que mostra como é feita a *distribuição dos graus nos nós*.
# Então seguem medidas de *clustering*, includindo clustering de tetraedros, que buscam mostrar o quão agrupada a rede está. Essas estruturas são muito presentes em Álgebra Topológica.
#
# Há um plot da rede com a *divisão de comunidades* realizadas através do algoritmo de Louvain - os tamanhos dos nós indicam o grau. Aqui buscamos apenas uma visualização da disposição da rede, e não de medidas.
#
# Para buscar entender a topologia da rede, há um *teste de robustez*, com ataques direcionados e aleatórios.
#
# Vamos então gerar os grafos.

# %%
er_graph.core()
er_graph.deg_graph()
er_graph.clustering()
plot_with_communities(er_graph.G)
er_graph.robustness()
# Out:
# Clustering:
# Clustering coefficient: 0.018504368352665567
# Clustering standart deviation 0.025114653161190624
# Tetrahedron Clustering:  0

# %%
ws_graph.core()
ws_graph.deg_graph()
ws_graph.clustering()
plot_with_communities(ws_graph.G)
ws_graph.robustness()
# Out:
# Clustering:
# Clustering coefficient: 0.23653419913419912
# Clustering standart deviation 0.10638257816654809
# Tetrahedron Clustering:  0.03872562437562438

# %%
ba_graph.core()
ba_graph.deg_graph()
ba_graph.clustering()
plot_with_communities(ba_graph.G)
ba_graph.robustness()
# Out:
# Clustering:
# Clustering coefficient: 0.06706768309184406
# Clustering standart deviation 0.07631402570572954
# Tetrahedron Clustering:  0.0020708335933720978

# %% [markdown]
# Após visualizar uma prévia da rede podemos ver a distribuição do grau. Nos dois primeiros grafos há uma distribuição normal, sendo que a Erdos Renyi é a mais próxima. No gráfico da rede BA notamos a presença de uma cauda, indicando a presença de Hubs.
#
# Já ao checar as medidas de clustering, vemos que são pequenas em ER e BA, mas grandes na rede Watts-Strogatz, devido a natureza da rede. Também é interessante checar o Clustering Tetraédrico, que indica a fração total de simplex 4D dentre os possíveis.
#
# O gráfico com a disposição das comunidas busca mostrar a divisão entre as comunidades. São mais aparentes em redes com clustering normal e tetraédrico elevado. Além disso, a rede BA apresenta Hubs de acordo com a imagem, como previsto no primeiro gráfico.
#
# Por fim, ao realizar os ataques, percebemos que as redes com mais Hubs são mais suscetíveis a ataques/falhas.
