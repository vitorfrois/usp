# %% [markdown]
# # Avaliação de Redes Complexas

# %% [markdown]
# Nome: Vítor Amorim Fróis
# NUSP: 12543440

# %% [markdown]
# <hr>

# %% [markdown]
# Inicialmente são feitos imports e funções que serão utilizadas ao longo do notebook.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import math
import EoN
import random as random
import statistics as stat
import scipy

# %%
def process_graph(G):
    G = G.to_undirected()
    G.remove_edges_from(nx.selfloop_edges(G))
    Gcc = sorted(nx.connected_components(G), key=len, reverse=True)
    G = G.subgraph(Gcc[0])
    G = nx.convert_node_labels_to_integers(G)
    return G

# %%
def shannon_entropy(G):
    k,Pk = degree_distribution(G)
    H = 0
    for p in Pk:
        if(p > 0):
            H = H - p*math.log(p, 2)
    return H

# %%
def get_all_degrees(G):
  degrees = []
  for node in G.nodes:
    degrees.append(G.degree[node])
  return degrees

# %%
def degree_distribution(G):
    vk = dict(G.degree())
    vk = list(vk.values()) # we get only the degree values
    maxk = np.max(vk)
    mink = np.min(min)
    kvalues = np.arange(0,maxk+1) # possible values of k
    Pk = np.zeros(maxk+1) # P(k)
    for k in vk:
        Pk[k] = Pk[k] + 1
    Pk = Pk/sum(Pk) # the sum of the elements of P(k) must to be equal to one
    return kvalues,Pk

# %%
def momment(G,m):
    M = 0
    N = len(G)
    for i in G.nodes:
        M = M + G.degree(i)**m
    M = M/N**m
    return M

# %% [markdown]
# **1 -** (a) Crie o gráfo a seguir usando a biblioteca networkx e mostre o gráfo.<br>
# Link para visualizar o grafo: https://commons.wikimedia.org/wiki/File:6n-graf.png<br>

# %%
G = nx.Graph()
edge_list = [(1, 2), (2, 3), (3, 4), (1, 5), (4, 5), (4, 6)]
G.add_edges_from(edge_list)

# %%
plt.figure(1,figsize=(3,3)) 
nx.draw(G, with_labels=True, node_size=1000)

# %% [markdown]
# (b) Simule uma caminha aleatória nesse grafo e monte uma matriz onde o elemento Mij representa o número de visitas ao vértice j dado que a caminhada iniciou em i. Considere pelo menos 100 passos. Compare o número de visitas com a medida eigenvector centrality de cada vértice.

# %%
nodes_list = list(G.nodes())
n_nodes = (len(nodes_list))
M = []
T = 100
for seed_node in nodes_list:
    ng = G.neighbors(seed_node)
    walk_p = np.zeros(n_nodes)
    for t in range(0,T):
        next_node = random.choice(list(ng))
        ng = G.neighbors(next_node)
        walk_p[next_node - 1] += 1
    M.append(walk_p)
M = np.array(M)
print(f'Matriz M: \n{M}')
M_sum = np.sum(M, axis=0)
print(f'A soma das colunas representa o total de vezes que o vértice foi visitado durante as iterações: \n{M_sum}')
# Out:
# Matriz M:
# [[22. 17. 12. 21. 19.  9.]
#  [11. 15. 21. 30. 17.  6.]
#  [20. 16. 13. 24. 18.  9.]
#  [18. 15. 15. 24. 18. 10.]
#  [13. 16. 20. 27. 16.  8.]
#  [29. 22.  9. 16. 18.  6.]]
# A soma das colunas representa o total de vezes que o vértice foi visitado durante as iterações:
# [113. 101.  90. 142. 106.  48.]

# %%
eig = list(nx.eigenvector_centrality(G).values())
eig
# Out:
# [0.3851210254201053,
#  0.3851210254201053,
#  0.4293744388249957,
#  0.5229658034947686,
#  0.4293744388249957,
#  0.24727624734544199]

# %%
stat.correlation(M_sum, eig)
# Out:
# 0.9178416854206368

# %% [markdown]
# Ao checar a correlação entre os dois métodos, obtemos um valor alto. Isso se deve ao fato de que os valores foram obtidos para uma mesma medida através de caminhos diferentes (método iterativo e da potência).

# %% [markdown]
# <hr>

# %% [markdown]
# **2 -** (a) Leia a rede do arquivo advogato.txt e mostre a distribuição acumulada complementar do grau, isto é, $P(K > k)$.

# %%
G = nx.convert_node_labels_to_integers(nx.read_edgelist('data-prova/advogato.txt'))

# %%
k, Pk = degree_distribution(G)
inv_cumsum = 1 - np.cumsum(Pk)

# %%
# determine best fit line

plt.loglog(k, inv_cumsum, 'o')

print(xl, yl)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.xlabel('k')
plt.ylabel('Pa(k)')
plt.title('Distribuição acumulada complementar do grau')
plt.show()
# Out:
# [0, 805] [0.0, 0.9432282546238216]

# %% [markdown]
# Pelo gráfico, é possível perceber uma distribuição baseada na lei de potência, indicando que a rede possui baixa homofilia. Podemos confirmar isso com o coeficiente de assortatividade.

# %%
nx.degree_assortativity_coefficient(G)
# Out:
# -0.07694795994236779

# %% [markdown]
# (b) Mostre o gráfico de Knn(k), ou seja, o grau médio dos vizinhos dos vértices de grau k em função do grau k.

# %%
knn = np.array(list(nx.average_neighbor_degree(G, nodes=G.nodes()).values()))

vk = dict(G.degree())
vk = list(vk.values())

knnk = list()
ks = list()
for k in np.arange(np.min(vk), np.max(vk)+1):
    aux = vk == k
    if(len(knn[aux]) > 0):
        av_knn = np.mean(knn[aux]) #average clustering among all the nodes with degree k
        knnk.append(av_knn)
        ks.append(k)
        
fig = plt.figure(figsize=(10,6))

# %%
plt.xlabel('ks')
plt.ylabel('knnk')
plt.title('Grau médio dos vizinhos dos vértices de grau k em função do grau k')
plt.plot(ks, knnk, 'o')

# %% [markdown]
# (c) Calcule a matriz de menores distâncias $D$ a matriz $A^n$, que presenta o número de caminhadas de comprimento $n$ entre cada par de vértices. Faça um gráfico da correlação entre $D_{ij}$ e $A_{ij}$ para diferentes valores de $n$. Ou seja, um gráfico em que o eixo x representa n e o y, a correlação entre essas duas matrizes.

# %%
G = process_graph(G)
array = nx.to_numpy_array(G)
csr = scipy.sparse.csr_matrix(array)
D = (scipy.sparse.csgraph.shortest_path(csr))
D_elements = D.flatten()

# %%
A = array

# %%
x = []
y = []

A = array

for n in range(6):
    x.append(n)
    A_elements = A.flatten()
    y.append(stat.correlation(A_elements, D_elements))
    A_power = np.linalg.matrix_power(A, 2)
    A = A_power

# %%
plt.xlabel('n')
plt.ylabel('Correlação entre $A^n$ e $D$')
plt.title('Correlação entre $A^n$ e $D$ por $n$')
plt.plot(x, y, 'b')
plt.figure(figsize=(10,6))

# %% [markdown]
# <hr>

# %% [markdown]
# **3 -** Considere a rede do arquivo internet_routers-22july06.gml. Escreva um código que calcule as seguintes medidas: (a) grau médio, (b) transitividade, (c) segundo momento da distribuição do grau, (d) entropia de Shannon da distribuição do grau, (e) coeficiente de assortatividade. Considere apenas o maior componente. Armazene os valores em uma lista e imprima essa lista, indicando os valores de cada medida.

# %%
routers = nx.read_gml('data-prova/internet_routers-22july06.gml')

# %%
average_degree = momment(G, 1)
transitivity = nx.transitivity(G)
G_momment = momment(G, 2)
G_shannon = shannon_entropy(G)
G_assortativity = nx.degree_assortativity_coefficient(G)

# %%
print('Grau médio: ', average_degree)
print('Transitividade: ', transitivity)
print('Segundo momento do grau: ', G_momment)
print('Entropia de Shannon: ', G_shannon)
print('Coeficiente de assortatividade: ', G_assortativity)
# Out:
# Grau médio:  4.218612550624918
# Transitividade:  0.011146383847822162
# Segundo momento do grau:  0.048033802976160965
# Entropia de Shannon:  2.3657964585920395
# Coeficiente de assortatividade:  -0.1983848751205647

# %% [markdown]
# <hr>

# %% [markdown]
# **4 -** Simule o modelo de propagação de epidemias SIR na rede de aeroportos dos EUA (USairport_2010.txt). Calcule a correlação de Pearson entre a fração final de recuperados e as seguintes medidas de centralidade: (a) grau, (b) betweenness centrality, (c) eigenvector centrality, (d) closenness centrality. Mostre os resultados e indique a maior correlação. Considere $\beta = 0.6$ e $\mu = 0.1$ no modelo SIR.

# %%
G = nx.read_edgelist('data-prova/USairport_2010.txt')

# %%
beta = 0.05
mi = 0.1
seed_list = list(G.nodes())
n = len(seed_list)
R_rate_list = []
degree_list = []
bet_list = []
eigen_list = []
close_list = []

# %%
all_deg_list = nx.degree(G)
all_eig_list = nx.eigenvector_centrality(G)
all_bet_list = nx.betweenness_centrality(G)
all_close_list = nx.closeness_centrality(G)

# %%
for seed in seed_list:
    times, S, I, R = EoN.fast_SIR(G, beta, mi, [seed])
    degree_list.append(all_deg_list[seed])
    bet_list.append(all_eig_list[seed])
    eigen_list.append(all_eig_list[seed])
    close_list.append(all_close_list[seed])
    R_rate_list.append(R[-1]/n)
    print(f'Last time info (seed = {seed}): {S[-1]}, {I[-1]}, {R[-1]}')
# Out:
# Last time info (seed = 1): 1573, 0, 1
# Last time info (seed = 47): 415, 0, 1159
# Last time info (seed = 832): 367, 0, 1207
# Last time info (seed = 2): 431, 0, 1143
# Last time info (seed = 679): 372, 0, 1202
# Last time info (seed = 3): 1573, 0, 1
# Last time info (seed = 424): 439, 0, 1135
# Last time info (seed = 1688): 418, 0, 1156
# Last time info (seed = 4): 1573, 0, 1
# Last time info (seed = 685): 450, 0, 1124
# Last time info (seed = 6): 1573, 0, 1
# Last time info (seed = 7): 1573, 0, 1
# Last time info (seed = 8): 1573, 0, 1
# Last time info (seed = 1217): 391, 0, 1183
# Last time info (seed = 1729): 395, 0, 1179
# Last time info (seed = 9): 1573, 0, 1
# Last time info (seed = 91): 395, 0, 1179
# Last time info (seed = 11): 437, 0, 1137
# Last time info (seed = 1494): 379, 0, 1195
# Last time info (seed = 12): 395, 0, 1179
# Last time info (seed = 227): 458, 0, 1116
# Last time info (seed = 505): 417, 0, 1157
# Last time info (seed = 509): 445, 0, 1129
# Last time info (seed = 13): 1573, 0, 1
# Last time info (seed = 15): 1573, 0, 1
# Last time info (seed = 16): 441, 0, 1133
# Last time info (seed = 844): 454, 0, 1120
# Last time info (seed = 17): 1573, 0, 1
# Last time info (seed = 19): 1573, 0, 1
# Last time info (seed = 20): 1573, 0, 1
# Last time info (seed = 70): 412, 0, 1162
# Last time info (seed = 88): 425, 0, 1149
# Last time info (seed = 464): 431, 0, 1143
# Last time info (seed = 1131): 1573, 0, 1
# Last time info (seed = 1262): 376, 0, 1198
# Last time info (seed = 1652): 1573, 0, 1
# Last time info (seed = 1739): 424, 0, 1150
# Last time info (seed = 21): 1573, 0, 1
# Last time info (seed = 22): 402, 0, 1172
# Last time info (seed = 23): 1573, 0, 1
# Last time info (seed = 24): 1573, 0, 1
# Last time info (seed = 27): 417, 0, 1157
# Last time info (seed = 1416): 412, 0, 1162
# Last time info (seed = 29): 403, 0, 1171
# Last time info (seed = 78): 407, 0, 1167
# Last time info (seed = 114): 358, 0, 1216
# Last time info (seed = 117): 395, 0, 1179
# Last time info (seed = 134): 457, 0, 1117
# Last time info (seed = 169): 385, 0, 1189
# Last time info (seed = 173): 422, 0, 1152
# Last time info (seed = 206): 443, 0, 1131
# Last time info (seed = 296): 385, 0, 1189
# Last time info (seed = 300): 460, 0, 1114
# Last time info (seed = 311): 363, 0, 1211
# Last time info (seed = 317): 402, 0, 1172
# Last time info (seed = 381): 490, 0, 1084
# Last time info (seed = 391): 429, 0, 1145
# Last time info (seed = 403): 429, 0, 1145
# Last time info (seed = 432): 415, 0, 1159
# Last time info (seed = 435): 397, 0, 1177
# Last time info (seed = 489): 485, 0, 1089
# Last time info (seed = 526): 445, 0, 1129
# Last time info (seed = 534): 403, 0, 1171
# Last time info (seed = 576): 393, 0, 1181
# Last time info (seed = 609): 470, 0, 1104
# Last time info (seed = 610): 440, 0, 1134
# Last time info (seed = 619): 421, 0, 1153
# Last time info (seed = 691): 417, 0, 1157
# Last time info (seed = 709): 423, 0, 1151
# Last time info (seed = 716): 460, 0, 1114
# Last time info (seed = 727): 447, 0, 1127
# Last time info (seed = 731): 441, 0, 1133
# Last time info (seed = 760): 374, 0, 1200
# Last time info (seed = 766): 375, 0, 1199
# Last time info (seed = 880): 415, 0, 1159
# Last time info (seed = 899): 418, 0, 1156
# Last time info (seed = 902): 430, 0, 1144
# Last time info (seed = 918): 443, 0, 1131
# Last time info (seed = 978): 437, 0, 1137
# Last time info (seed = 982): 428, 0, 1146
# Last time info (seed = 989): 449, 0, 1125
# Last time info (seed = 994): 401, 0, 1173
# Last time info (seed = 1022): 381, 0, 1193
# Last time info (seed = 1029): 410, 0, 1164
# Last time info (seed = 1066): 430, 0, 1144
# Last time info (seed = 1101): 428, 0, 1146
# Last time info (seed = 1109): 421, 0, 1153
# Last time info (seed = 1200): 369, 0, 1205
# Last time info (seed = 1246): 379, 0, 1195
# Last time info (seed = 1252): 471, 0, 1103
# Last time info (seed = 1258): 1573, 0, 1
# Last time info (seed = 1264): 384, 0, 1190
# Last time info (seed = 1270): 1573, 0, 1
# Last time info (seed = 1313): 409, 0, 1165
# Last time info (seed = 1359): 407, 0, 1167
# Last time info (seed = 1374): 389, 0, 1185
# Last time info (seed = 1391): 411, 0, 1163
# Last time info (seed = 1435): 455, 0, 1119
# Last time info (seed = 1460): 399, 0, 1175
# Last time info (seed = 1463): 409, 0, 1165
# Last time info (seed = 1504): 394, 0, 1180
# Last time info (seed = 1517): 504, 0, 1070
# Last time info (seed = 1628): 438, 0, 1136
# Last time info (seed = 1664): 433, 0, 1141
# Last time info (seed = 1700): 393, 0, 1181
# Last time info (seed = 1837): 451, 0, 1123
# Last time info (seed = 30): 450, 0, 1124
# Last time info (seed = 478): 405, 0, 1169
# Last time info (seed = 485): 438, 0, 1136
# Last time info (seed = 590): 1573, 0, 1
# Last time info (seed = 719): 484, 0, 1090
# Last time info (seed = 1461): 412, 0, 1162
# Last time info (seed = 1470): 448, 0, 1126
# Last time info (seed = 1482): 426, 0, 1148
# Last time info (seed = 31): 345, 0, 1229
# Last time info (seed = 185): 424, 0, 1150
# Last time info (seed = 600): 390, 0, 1184
# Last time info (seed = 712): 410, 0, 1164
# Last time info (seed = 1165): 1573, 0, 1
# Last time info (seed = 1207): 372, 0, 1202
# Last time info (seed = 1349): 431, 0, 1143
# Last time info (seed = 1446): 401, 0, 1173
# Last time info (seed = 1742): 420, 0, 1154
# Last time info (seed = 32): 462, 0, 1112
# Last time info (seed = 75): 401, 0, 1173
# Last time info (seed = 76): 1572, 0, 2
# Last time info (seed = 82): 417, 0, 1157
# Last time info (seed = 123): 416, 0, 1158
# Last time info (seed = 145): 472, 0, 1102
# Last time info (seed = 158): 408, 0, 1166
# Last time info (seed = 176): 469, 0, 1105
# Last time info (seed = 211): 425, 0, 1149
# Last time info (seed = 215): 438, 0, 1136
# Last time info (seed = 216): 461, 0, 1113
# Last time info (seed = 239): 428, 0, 1146
# Last time info (seed = 240): 441, 0, 1133
# Last time info (seed = 246): 368, 0, 1206
# Last time info (seed = 321): 402, 0, 1172
# Last time info (seed = 327): 387, 0, 1187
# Last time info (seed = 334): 436, 0, 1138
# Last time info (seed = 343): 369, 0, 1205
# Last time info (seed = 355): 1573, 0, 1
# Last time info (seed = 356): 433, 0, 1141
# Last time info (seed = 358): 1573, 0, 1
# Last time info (seed = 379): 447, 0, 1127
# Last time info (seed = 383): 417, 0, 1157
# Last time info (seed = 389): 418, 0, 1156
# Last time info (seed = 452): 419, 0, 1155
# Last time info (seed = 494): 1573, 0, 1
# Last time info (seed = 500): 425, 0, 1149
# Last time info (seed = 507): 432, 0, 1142
# Last time info (seed = 585): 1573, 0, 1
# Last time info (seed = 595): 430, 0, 1144
# Last time info (seed = 612): 494, 0, 1080
# Last time info (seed = 622): 419, 0, 1155
# Last time info (seed = 677): 1573, 0, 1
# Last time info (seed = 683): 379, 0, 1195
# Last time info (seed = 686): 416, 0, 1158
# Last time info (seed = 711): 402, 0, 1172
# Last time info (seed = 718): 442, 0, 1132
# Last time info (seed = 749): 453, 0, 1121
# Last time info (seed = 757): 413, 0, 1161
# Last time info (seed = 874): 440, 0, 1134
# Last time info (seed = 875): 433, 0, 1141
# Last time info (seed = 877): 417, 0, 1157
# Last time info (seed = 879): 431, 0, 1143
# Last time info (seed = 903): 400, 0, 1174
# Last time info (seed = 964): 428, 0, 1146
# Last time info (seed = 997): 408, 0, 1166
# Last time info (seed = 998): 415, 0, 1159
# Last time info (seed = 1011): 471, 0, 1103
# Last time info (seed = 1047): 406, 0, 1168
# Last time info (seed = 1061): 453, 0, 1121
# Last time info (seed = 1068): 452, 0, 1122
# Last time info (seed = 1072): 433, 0, 1141
# Last time info (seed = 1162): 393, 0, 1181
# Last time info (seed = 1176): 428, 0, 1146
# Last time info (seed = 1185): 483, 0, 1091
# Last time info (seed = 1189): 404, 0, 1170
# Last time info (seed = 1201): 442, 0, 1132
# Last time info (seed = 1231): 409, 0, 1165
# Last time info (seed = 1240): 408, 0, 1166
# Last time info (seed = 1255): 370, 0, 1204
# Last time info (seed = 1297): 367, 0, 1207
# Last time info (seed = 1304): 402, 0, 1172
# Last time info (seed = 1320): 450, 0, 1124
# Last time info (seed = 1322): 377, 0, 1197
# Last time info (seed = 1353): 477, 0, 1097
# Last time info (seed = 1372): 451, 0, 1123
# Last time info (seed = 1403): 450, 0, 1124
# Last time info (seed = 1405): 397, 0, 1177
# Last time info (seed = 1408): 446, 0, 1128
# Last time info (seed = 1413): 1573, 0, 1
# Last time info (seed = 1426): 410, 0, 1164
# Last time info (seed = 1433): 391, 0, 1183
# Last time info (seed = 1437): 417, 0, 1157
# Last time info (seed = 1456): 441, 0, 1133
# Last time info (seed = 1457): 418, 0, 1156
# Last time info (seed = 1480): 365, 0, 1209
# Last time info (seed = 1485): 403, 0, 1171
# Last time info (seed = 1529): 1573, 0, 1
# Last time info (seed = 1596): 380, 0, 1194
# Last time info (seed = 1613): 417, 0, 1157
# Last time info (seed = 1630): 455, 0, 1119
# Last time info (seed = 1822): 358, 0, 1216
# Last time info (seed = 1831): 385, 0, 1189
# Last time info (seed = 33): 414, 0, 1160
# Last time info (seed = 118): 382, 0, 1192
# Last time info (seed = 34): 478, 0, 1096
# Last time info (seed = 35): 435, 0, 1139
# Last time info (seed = 598): 428, 0, 1146
# Last time info (seed = 1820): 429, 0, 1145
# Last time info (seed = 36): 368, 0, 1206
# Last time info (seed = 1428): 432, 0, 1142
# Last time info (seed = 37): 415, 0, 1159
# Last time info (seed = 38): 430, 0, 1144
# Last time info (seed = 146): 1572, 0, 2
# Last time info (seed = 348): 373, 0, 1201
# Last time info (seed = 498): 402, 0, 1172
# Last time info (seed = 545): 414, 0, 1160
# Last time info (seed = 631): 388, 0, 1186
# Last time info (seed = 651): 1573, 0, 1
# Last time info (seed = 692): 428, 0, 1146
# Last time info (seed = 700): 465, 0, 1109
# Last time info (seed = 702): 440, 0, 1134
# Last time info (seed = 1037): 447, 0, 1127
# Last time info (seed = 1090): 503, 0, 1071
# Last time info (seed = 1220): 1573, 0, 1
# Last time info (seed = 1221): 436, 0, 1138
# Last time info (seed = 1573): 427, 0, 1147
# Last time info (seed = 1847): 420, 0, 1154
# Last time info (seed = 1858): 429, 0, 1145
# Last time info (seed = 39): 401, 0, 1173
# Last time info (seed = 335): 1573, 0, 1
# Last time info (seed = 536): 439, 0, 1135
# Last time info (seed = 872): 457, 0, 1117
# Last time info (seed = 1008): 400, 0, 1174
# Last time info (seed = 1541): 459, 0, 1115
# Last time info (seed = 1629): 424, 0, 1150
# Last time info (seed = 1645): 408, 0, 1166
# Last time info (seed = 40): 407, 0, 1167
# Last time info (seed = 196): 408, 0, 1166
# Last time info (seed = 271): 417, 0, 1157
# Last time info (seed = 1350): 371, 0, 1203
# Last time info (seed = 41): 422, 0, 1152
# Last time info (seed = 60): 384, 0, 1190
# Last time info (seed = 218): 393, 0, 1181
# Last time info (seed = 238): 458, 0, 1116
# Last time info (seed = 256): 369, 0, 1205
# Last time info (seed = 258): 404, 0, 1170
# Last time info (seed = 272): 1573, 0, 1
# Last time info (seed = 344): 468, 0, 1106
# Last time info (seed = 353): 428, 0, 1146
# Last time info (seed = 361): 1573, 0, 1
# Last time info (seed = 375): 396, 0, 1178
# Last time info (seed = 508): 414, 0, 1160
# Last time info (seed = 560): 403, 0, 1171
# Last time info (seed = 613): 424, 0, 1150
# Last time info (seed = 618): 428, 0, 1146
# Last time info (seed = 635): 418, 0, 1156
# Last time info (seed = 748): 400, 0, 1174
# Last time info (seed = 780): 407, 0, 1167
# Last time info (seed = 926): 411, 0, 1163
# Last time info (seed = 947): 424, 0, 1150
# Last time info (seed = 970): 445, 0, 1129
# Last time info (seed = 1043): 394, 0, 1180
# Last time info (seed = 1202): 1573, 0, 1
# Last time info (seed = 1250): 388, 0, 1186
# Last time info (seed = 1328): 382, 0, 1192
# Last time info (seed = 1368): 313, 0, 1261
# Last time info (seed = 1376): 400, 0, 1174
# Last time info (seed = 1406): 340, 0, 1234
# Last time info (seed = 1462): 412, 0, 1162
# Last time info (seed = 1549): 396, 0, 1178
# Last time info (seed = 1611): 1573, 0, 1
# Last time info (seed = 1617): 378, 0, 1196
# Last time info (seed = 1698): 438, 0, 1136
# Last time info (seed = 1785): 405, 0, 1169
# Last time info (seed = 1795): 375, 0, 1199
# Last time info (seed = 43): 1573, 0, 1
# Last time info (seed = 45): 1573, 0, 1
# Last time info (seed = 14): 1573, 0, 1
# Last time info (seed = 68): 443, 0, 1131
# Last time info (seed = 81): 435, 0, 1139
# Last time info (seed = 97): 1573, 0, 1
# Last time info (seed = 99): 1573, 0, 1
# Last time info (seed = 153): 1573, 0, 1
# Last time info (seed = 269): 1573, 0, 1
# Last time info (seed = 392): 417, 0, 1157
# Last time info (seed = 402): 1573, 0, 1
# Last time info (seed = 410): 1573, 0, 1
# Last time info (seed = 440): 391, 0, 1183
# Last time info (seed = 483): 1573, 0, 1
# Last time info (seed = 743): 332, 0, 1242
# Last time info (seed = 793): 414, 0, 1160
# Last time info (seed = 815): 1573, 0, 1
# Last time info (seed = 820): 1572, 0, 2
# Last time info (seed = 825): 362, 0, 1212
# Last time info (seed = 831): 399, 0, 1175
# Last time info (seed = 837): 1573, 0, 1
# Last time info (seed = 839): 455, 0, 1119
# Last time info (seed = 861): 398, 0, 1176
# Last time info (seed = 864): 405, 0, 1169
# Last time info (seed = 1181): 1573, 0, 1
# Last time info (seed = 1203): 381, 0, 1193
# Last time info (seed = 1307): 400, 0, 1174
# Last time info (seed = 1465): 410, 0, 1164
# Last time info (seed = 1477): 484, 0, 1090
# Last time info (seed = 1547): 397, 0, 1177
# Last time info (seed = 1609): 416, 0, 1158
# Last time info (seed = 1653): 1573, 0, 1
# Last time info (seed = 1715): 1573, 0, 1
# Last time info (seed = 49): 446, 0, 1128
# Last time info (seed = 126): 387, 0, 1187
# Last time info (seed = 156): 387, 0, 1187
# Last time info (seed = 976): 431, 0, 1143
# Last time info (seed = 1016): 453, 0, 1121
# Last time info (seed = 1111): 1572, 0, 2
# Last time info (seed = 1118): 1573, 0, 1
# Last time info (seed = 1133): 460, 0, 1114
# Last time info (seed = 1279): 430, 0, 1144
# Last time info (seed = 1280): 434, 0, 1140
# Last time info (seed = 1602): 356, 0, 1218
# Last time info (seed = 50): 1573, 0, 1
# Last time info (seed = 51): 427, 0, 1147
# Last time info (seed = 71): 430, 0, 1144
# Last time info (seed = 236): 378, 0, 1196
# Last time info (seed = 365): 407, 0, 1167
# Last time info (seed = 567): 419, 0, 1155
# Last time info (seed = 689): 410, 0, 1164
# Last time info (seed = 696): 427, 0, 1147
# Last time info (seed = 787): 425, 0, 1149
# Last time info (seed = 1040): 461, 0, 1113
# Last time info (seed = 1145): 401, 0, 1173
# Last time info (seed = 1346): 440, 0, 1134
# Last time info (seed = 1536): 379, 0, 1195
# Last time info (seed = 1557): 434, 0, 1140
# Last time info (seed = 52): 405, 0, 1169
# Last time info (seed = 133): 440, 0, 1134
# Last time info (seed = 209): 377, 0, 1197
# Last time info (seed = 345): 400, 0, 1174
# Last time info (seed = 371): 444, 0, 1130
# Last time info (seed = 418): 417, 0, 1157
# Last time info (seed = 420): 369, 0, 1205
# Last time info (seed = 588): 372, 0, 1202
# Last time info (seed = 625): 470, 0, 1104
# Last time info (seed = 632): 1573, 0, 1
# Last time info (seed = 812): 400, 0, 1174
# Last time info (seed = 936): 395, 0, 1179
# Last time info (seed = 988): 396, 0, 1178
# Last time info (seed = 1361): 373, 0, 1201
# Last time info (seed = 1402): 423, 0, 1151
# Last time info (seed = 1404): 445, 0, 1129
# Last time info (seed = 1411): 458, 0, 1116
# Last time info (seed = 1430): 1573, 0, 1
# Last time info (seed = 1438): 402, 0, 1172
# Last time info (seed = 1579): 393, 0, 1181
# Last time info (seed = 53): 1573, 0, 1
# Last time info (seed = 55): 404, 0, 1170
# Last time info (seed = 151): 421, 0, 1153
# Last time info (seed = 56): 1573, 0, 1
# Last time info (seed = 735): 403, 0, 1171
# Last time info (seed = 778): 444, 0, 1130
# Last time info (seed = 57): 1573, 0, 1
# Last time info (seed = 58): 465, 0, 1109
# Last time info (seed = 775): 412, 0, 1162
# Last time info (seed = 786): 397, 0, 1177
# Last time info (seed = 1455): 1573, 0, 1
# Last time info (seed = 1588): 1573, 0, 1
# Last time info (seed = 59): 473, 0, 1101
# Last time info (seed = 217): 369, 0, 1205
# Last time info (seed = 605): 421, 0, 1153
# Last time info (seed = 1004): 480, 0, 1094
# Last time info (seed = 1139): 432, 0, 1142
# Last time info (seed = 1450): 415, 0, 1159
# Last time info (seed = 1752): 425, 0, 1149
# Last time info (seed = 62): 398, 0, 1176
# Last time info (seed = 63): 387, 0, 1187
# Last time info (seed = 234): 479, 0, 1095
# Last time info (seed = 565): 470, 0, 1104
# Last time info (seed = 623): 416, 0, 1158
# Last time info (seed = 981): 1573, 0, 1
# Last time info (seed = 1025): 430, 0, 1144
# Last time info (seed = 1567): 432, 0, 1142
# Last time info (seed = 64): 413, 0, 1161
# Last time info (seed = 155): 1573, 0, 1
# Last time info (seed = 1263): 411, 0, 1163
# Last time info (seed = 65): 377, 0, 1197
# Last time info (seed = 113): 434, 0, 1140
# Last time info (seed = 231): 388, 0, 1186
# Last time info (seed = 1144): 406, 0, 1168
# Last time info (seed = 1254): 390, 0, 1184
# Last time info (seed = 1265): 503, 0, 1071
# Last time info (seed = 66): 392, 0, 1182
# Last time info (seed = 724): 422, 0, 1152
# Last time info (seed = 67): 374, 0, 1200
# Last time info (seed = 152): 436, 0, 1138
# Last time info (seed = 458): 427, 0, 1147
# Last time info (seed = 482): 434, 0, 1140
# Last time info (seed = 604): 478, 0, 1096
# Last time info (seed = 817): 1570, 0, 4
# Last time info (seed = 818): 365, 0, 1209
# Last time info (seed = 836): 520, 0, 1054
# Last time info (seed = 851): 404, 0, 1170
# Last time info (seed = 862): 408, 0, 1166
# Last time info (seed = 1030): 383, 0, 1191
# Last time info (seed = 1146): 426, 0, 1148
# Last time info (seed = 1190): 385, 0, 1189
# Last time info (seed = 1266): 387, 0, 1187
# Last time info (seed = 1290): 439, 0, 1135
# Last time info (seed = 1387): 395, 0, 1179
# Last time info (seed = 1544): 405, 0, 1169
# Last time info (seed = 1601): 437, 0, 1137
# Last time info (seed = 1677): 433, 0, 1141
# Last time info (seed = 1733): 434, 0, 1140
# Last time info (seed = 1743): 394, 0, 1180
# Last time info (seed = 69): 386, 0, 1188
# Last time info (seed = 674): 435, 0, 1139
# Last time info (seed = 230): 1573, 0, 1
# Last time info (seed = 264): 411, 0, 1163
# Last time info (seed = 279): 1573, 0, 1
# Last time info (seed = 308): 425, 0, 1149
# Last time info (seed = 421): 415, 0, 1159
# Last time info (seed = 587): 405, 0, 1169
# Last time info (seed = 720): 423, 0, 1151
# Last time info (seed = 726): 429, 0, 1145
# Last time info (seed = 794): 443, 0, 1131
# Last time info (seed = 796): 413, 0, 1161
# Last time info (seed = 803): 407, 0, 1167
# Last time info (seed = 805): 388, 0, 1186
# Last time info (seed = 816): 535, 0, 1039
# Last time info (seed = 819): 377, 0, 1197
# Last time info (seed = 823): 397, 0, 1177
# Last time info (seed = 826): 405, 0, 1169
# Last time info (seed = 827): 462, 0, 1112
# Last time info (seed = 838): 1570, 0, 4
# Last time info (seed = 854): 401, 0, 1173
# Last time info (seed = 922): 451, 0, 1123
# Last time info (seed = 1132): 352, 0, 1222
# Last time info (seed = 1194): 1573, 0, 1
# Last time info (seed = 1195): 1573, 0, 1
# Last time info (seed = 1197): 1573, 0, 1
# Last time info (seed = 1234): 420, 0, 1154
# Last time info (seed = 1235): 1573, 0, 1
# Last time info (seed = 1236): 363, 0, 1211
# Last time info (seed = 1271): 1573, 0, 1
# Last time info (seed = 1305): 414, 0, 1160
# Last time info (seed = 1345): 433, 0, 1141
# Last time info (seed = 1429): 398, 0, 1176
# Last time info (seed = 1683): 428, 0, 1146
# Last time info (seed = 1713): 1573, 0, 1
# Last time info (seed = 1714): 1573, 0, 1
# Last time info (seed = 1734): 417, 0, 1157
# Last time info (seed = 1370): 410, 0, 1164
# Last time info (seed = 1659): 427, 0, 1147
# Last time info (seed = 1721): 388, 0, 1186
# Last time info (seed = 1722): 378, 0, 1196
# Last time info (seed = 72): 1573, 0, 1
# Last time info (seed = 73): 1573, 0, 1
# Last time info (seed = 1780): 1571, 0, 3
# Last time info (seed = 106): 437, 0, 1137
# Last time info (seed = 127): 413, 0, 1161
# Last time info (seed = 237): 386, 0, 1188
# Last time info (seed = 293): 422, 0, 1152
# Last time info (seed = 759): 477, 0, 1097
# Last time info (seed = 972): 408, 0, 1166
# Last time info (seed = 1027): 471, 0, 1103
# Last time info (seed = 1069): 1573, 0, 1
# Last time info (seed = 1161): 425, 0, 1149
# Last time info (seed = 1172): 395, 0, 1179
# Last time info (seed = 1277): 444, 0, 1130
# Last time info (seed = 1390): 384, 0, 1190
# Last time info (seed = 1631): 406, 0, 1168
# Last time info (seed = 1782): 1573, 0, 1
# Last time info (seed = 1789): 1573, 0, 1
# Last time info (seed = 506): 387, 0, 1187
# Last time info (seed = 694): 432, 0, 1142
# Last time info (seed = 1091): 507, 0, 1067
# Last time info (seed = 79): 399, 0, 1175
# Last time info (seed = 80): 446, 0, 1128
# Last time info (seed = 876): 436, 0, 1138
# Last time info (seed = 83): 1573, 0, 1
# Last time info (seed = 85): 408, 0, 1166
# Last time info (seed = 434): 1573, 0, 1
# Last time info (seed = 86): 379, 0, 1195
# Last time info (seed = 87): 1572, 0, 2
# Last time info (seed = 1078): 1573, 0, 1
# Last time info (seed = 94): 444, 0, 1130
# Last time info (seed = 116): 1572, 0, 2
# Last time info (seed = 174): 398, 0, 1176
# Last time info (seed = 242): 443, 0, 1131
# Last time info (seed = 372): 516, 0, 1058
# Last time info (seed = 426): 1573, 0, 1
# Last time info (seed = 445): 365, 0, 1209
# Last time info (seed = 447): 419, 0, 1155
# Last time info (seed = 475): 423, 0, 1151
# Last time info (seed = 543): 451, 0, 1123
# Last time info (seed = 553): 1573, 0, 1
# Last time info (seed = 573): 480, 0, 1094
# Last time info (seed = 596): 401, 0, 1173
# Last time info (seed = 806): 424, 0, 1150
# Last time info (seed = 813): 440, 0, 1134
# Last time info (seed = 830): 460, 0, 1114
# Last time info (seed = 847): 393, 0, 1181
# Last time info (seed = 849): 436, 0, 1138
# Last time info (seed = 860): 461, 0, 1113
# Last time info (seed = 949): 445, 0, 1129
# Last time info (seed = 977): 372, 0, 1202
# Last time info (seed = 1102): 375, 0, 1199
# Last time info (seed = 1117): 409, 0, 1165
# Last time info (seed = 1121): 410, 0, 1164
# Last time info (seed = 1129): 415, 0, 1159
# Last time info (seed = 1171): 423, 0, 1151
# Last time info (seed = 1186): 434, 0, 1140
# Last time info (seed = 1224): 452, 0, 1122
# Last time info (seed = 1228): 422, 0, 1152
# Last time info (seed = 1243): 475, 0, 1099
# Last time info (seed = 1268): 1573, 0, 1
# Last time info (seed = 1284): 454, 0, 1120
# Last time info (seed = 1300): 395, 0, 1179
# Last time info (seed = 1310): 445, 0, 1129
# Last time info (seed = 1315): 413, 0, 1161
# Last time info (seed = 1354): 431, 0, 1143
# Last time info (seed = 1383): 372, 0, 1202
# Last time info (seed = 1451): 453, 0, 1121
# Last time info (seed = 1466): 438, 0, 1136
# Last time info (seed = 1476): 369, 0, 1205
# Last time info (seed = 1489): 1573, 0, 1
# Last time info (seed = 1514): 1573, 0, 1
# Last time info (seed = 1528): 462, 0, 1112
# Last time info (seed = 1539): 1573, 0, 1
# Last time info (seed = 1574): 1573, 0, 1
# Last time info (seed = 1597): 1573, 0, 1
# Last time info (seed = 1614): 401, 0, 1173
# Last time info (seed = 1660): 407, 0, 1167
# Last time info (seed = 1716): 405, 0, 1169
# Last time info (seed = 1718): 393, 0, 1181
# Last time info (seed = 1736): 1573, 0, 1
# Last time info (seed = 1762): 409, 0, 1165
# Last time info (seed = 1773): 459, 0, 1115
# Last time info (seed = 1774): 474, 0, 1100
# Last time info (seed = 1809): 418, 0, 1156
# Last time info (seed = 1819): 1573, 0, 1
# Last time info (seed = 1830): 1573, 0, 1
# Last time info (seed = 89): 1573, 0, 1
# Last time info (seed = 149): 411, 0, 1163
# Last time info (seed = 10): 1573, 0, 1
# Last time info (seed = 297): 446, 0, 1128
# Last time info (seed = 557): 1573, 0, 1
# Last time info (seed = 647): 349, 0, 1225
# Last time info (seed = 684): 408, 0, 1166
# Last time info (seed = 835): 417, 0, 1157
# Last time info (seed = 951): 360, 0, 1214
# Last time info (seed = 1505): 1573, 0, 1
# Last time info (seed = 1672): 433, 0, 1141
# Last time info (seed = 92): 1573, 0, 1
# Last time info (seed = 93): 344, 0, 1230
# Last time info (seed = 96): 419, 0, 1155
# Last time info (seed = 98): 469, 0, 1105
# Last time info (seed = 181): 400, 0, 1174
# Last time info (seed = 1618): 450, 0, 1124
# Last time info (seed = 100): 426, 0, 1148
# Last time info (seed = 101): 484, 0, 1090
# Last time info (seed = 303): 358, 0, 1216
# Last time info (seed = 102): 1573, 0, 1
# Last time info (seed = 104): 414, 0, 1160
# Last time info (seed = 273): 490, 0, 1084
# Last time info (seed = 302): 457, 0, 1117
# Last time info (seed = 564): 432, 0, 1142
# Last time info (seed = 1684): 1571, 0, 3
# Last time info (seed = 105): 1573, 0, 1
# Last time info (seed = 164): 1573, 0, 1
# Last time info (seed = 107): 385, 0, 1189
# Last time info (seed = 1138): 1573, 0, 1
# Last time info (seed = 108): 391, 0, 1183
# Last time info (seed = 758): 389, 0, 1185
# Last time info (seed = 110): 444, 0, 1130
# Last time info (seed = 112): 422, 0, 1152
# Last time info (seed = 119): 421, 0, 1153
# Last time info (seed = 142): 360, 0, 1214
# Last time info (seed = 144): 382, 0, 1192
# Last time info (seed = 162): 439, 0, 1135
# Last time info (seed = 187): 442, 0, 1132
# Last time info (seed = 189): 433, 0, 1141
# Last time info (seed = 204): 370, 0, 1204
# Last time info (seed = 213): 1573, 0, 1
# Last time info (seed = 1244): 345, 0, 1229
# Last time info (seed = 1251): 440, 0, 1134
# Last time info (seed = 1256): 367, 0, 1207
# Last time info (seed = 1259): 1573, 0, 1
# Last time info (seed = 1281): 423, 0, 1151
# Last time info (seed = 1293): 425, 0, 1149
# Last time info (seed = 1308): 430, 0, 1144
# Last time info (seed = 1312): 438, 0, 1136
# Last time info (seed = 1316): 406, 0, 1168
# Last time info (seed = 1375): 377, 0, 1197
# Last time info (seed = 1392): 1573, 0, 1
# Last time info (seed = 1421): 375, 0, 1199
# Last time info (seed = 1452): 414, 0, 1160
# Last time info (seed = 1454): 452, 0, 1122
# Last time info (seed = 1488): 415, 0, 1159
# Last time info (seed = 1520): 1573, 0, 1
# Last time info (seed = 1522): 412, 0, 1162
# Last time info (seed = 1523): 396, 0, 1178
# Last time info (seed = 1525): 336, 0, 1238
# Last time info (seed = 1534): 411, 0, 1163
# Last time info (seed = 1540): 429, 0, 1145
# Last time info (seed = 1543): 416, 0, 1158
# Last time info (seed = 1548): 385, 0, 1189
# Last time info (seed = 1555): 1573, 0, 1
# Last time info (seed = 1656): 415, 0, 1159
# Last time info (seed = 1671): 413, 0, 1161
# Last time info (seed = 1679): 441, 0, 1133
# Last time info (seed = 1696): 435, 0, 1139
# Last time info (seed = 1735): 1573, 0, 1
# Last time info (seed = 1783): 421, 0, 1153
# Last time info (seed = 1799): 399, 0, 1175
# Last time info (seed = 1836): 396, 0, 1178
# Last time info (seed = 115): 423, 0, 1151
# Last time info (seed = 1746): 433, 0, 1141
# Last time info (seed = 1339): 389, 0, 1185
# Last time info (seed = 1417): 472, 0, 1102
# Last time info (seed = 1527): 415, 0, 1159
# Last time info (seed = 1808): 1573, 0, 1
# Last time info (seed = 1823): 390, 0, 1184
# Last time info (seed = 120): 401, 0, 1173
# Last time info (seed = 167): 419, 0, 1155
# Last time info (seed = 1610): 1573, 0, 1
# Last time info (seed = 121): 384, 0, 1190
# Last time info (seed = 122): 457, 0, 1117
# Last time info (seed = 1048): 461, 0, 1113
# Last time info (seed = 1422): 393, 0, 1181
# Last time info (seed = 1481): 445, 0, 1129
# Last time info (seed = 1720): 1573, 0, 1
# Last time info (seed = 265): 460, 0, 1114
# Last time info (seed = 307): 399, 0, 1175
# Last time info (seed = 325): 436, 0, 1138
# Last time info (seed = 669): 394, 0, 1180
# Last time info (seed = 1021): 344, 0, 1230
# Last time info (seed = 1401): 435, 0, 1139
# Last time info (seed = 1418): 401, 0, 1173
# Last time info (seed = 1497): 383, 0, 1191
# Last time info (seed = 1568): 453, 0, 1121
# Last time info (seed = 1599): 1573, 0, 1
# Last time info (seed = 1626): 1573, 0, 1
# Last time info (seed = 1737): 1573, 0, 1
# Last time info (seed = 1843): 434, 0, 1140
# Last time info (seed = 191): 416, 0, 1158
# Last time info (seed = 1269): 1573, 0, 1
# Last time info (seed = 1803): 420, 0, 1154
# Last time info (seed = 940): 408, 0, 1166
# Last time info (seed = 128): 430, 0, 1144
# Last time info (seed = 129): 393, 0, 1181
# Last time info (seed = 130): 366, 0, 1208
# Last time info (seed = 131): 1573, 0, 1
# Last time info (seed = 179): 412, 0, 1162
# Last time info (seed = 347): 434, 0, 1140
# Last time info (seed = 532): 420, 0, 1154
# Last time info (seed = 551): 1573, 0, 1
# Last time info (seed = 611): 410, 0, 1164
# Last time info (seed = 1000): 377, 0, 1197
# Last time info (seed = 1067): 1573, 0, 1
# Last time info (seed = 1352): 445, 0, 1129
# Last time info (seed = 1356): 432, 0, 1142
# Last time info (seed = 1636): 404, 0, 1170
# Last time info (seed = 1682): 413, 0, 1161
# Last time info (seed = 135): 1573, 0, 1
# Last time info (seed = 136): 441, 0, 1133
# Last time info (seed = 943): 401, 0, 1173
# Last time info (seed = 137): 1573, 0, 1
# Last time info (seed = 138): 439, 0, 1135
# Last time info (seed = 139): 370, 0, 1204
# Last time info (seed = 140): 1573, 0, 1
# Last time info (seed = 1661): 1572, 0, 2
# Last time info (seed = 141): 1573, 0, 1
# Last time info (seed = 193): 1573, 0, 1
# Last time info (seed = 1245): 456, 0, 1118
# Last time info (seed = 143): 1573, 0, 1
# Last time info (seed = 944): 414, 0, 1160
# Last time info (seed = 148): 1573, 0, 1
# Last time info (seed = 223): 367, 0, 1207
# Last time info (seed = 882): 438, 0, 1136
# Last time info (seed = 150): 395, 0, 1179
# Last time info (seed = 459): 430, 0, 1144
# Last time info (seed = 369): 406, 0, 1168
# Last time info (seed = 465): 1573, 0, 1
# Last time info (seed = 859): 418, 0, 1156
# Last time info (seed = 1130): 357, 0, 1217
# Last time info (seed = 1570): 413, 0, 1161
# Last time info (seed = 1608): 380, 0, 1194
# Last time info (seed = 1634): 1573, 0, 1
# Last time info (seed = 1637): 391, 0, 1183
# Last time info (seed = 1846): 374, 0, 1200
# Last time info (seed = 154): 387, 0, 1187
# Last time info (seed = 437): 353, 0, 1221
# Last time info (seed = 524): 355, 0, 1219
# Last time info (seed = 769): 454, 0, 1120
# Last time info (seed = 747): 444, 0, 1130
# Last time info (seed = 881): 401, 0, 1173
# Last time info (seed = 1432): 391, 0, 1183
# Last time info (seed = 314): 1573, 0, 1
# Last time info (seed = 466): 416, 0, 1158
# Last time info (seed = 492): 1573, 0, 1
# Last time info (seed = 544): 441, 0, 1133
# Last time info (seed = 935): 430, 0, 1144
# Last time info (seed = 1188): 1573, 0, 1
# Last time info (seed = 1329): 414, 0, 1160
# Last time info (seed = 1347): 400, 0, 1174
# Last time info (seed = 1503): 1573, 0, 1
# Last time info (seed = 1707): 400, 0, 1174
# Last time info (seed = 1764): 1573, 0, 1
# Last time info (seed = 1767): 467, 0, 1107
# Last time info (seed = 1829): 1573, 0, 1
# Last time info (seed = 1834): 392, 0, 1182
# Last time info (seed = 1845): 1573, 0, 1
# Last time info (seed = 157): 1573, 0, 1
# Last time info (seed = 1484): 398, 0, 1176
# Last time info (seed = 159): 402, 0, 1172
# Last time info (seed = 160): 457, 0, 1117
# Last time info (seed = 161): 429, 0, 1145
# Last time info (seed = 163): 424, 0, 1150
# Last time info (seed = 710): 454, 0, 1120
# Last time info (seed = 725): 429, 0, 1145
# Last time info (seed = 897): 466, 0, 1108
# Last time info (seed = 913): 1573, 0, 1
# Last time info (seed = 1283): 417, 0, 1157
# Last time info (seed = 1439): 1573, 0, 1
# Last time info (seed = 1442): 325, 0, 1249
# Last time info (seed = 1458): 406, 0, 1168
# Last time info (seed = 1273): 396, 0, 1178
# Last time info (seed = 180): 1573, 0, 1
# Last time info (seed = 1748): 437, 0, 1137
# Last time info (seed = 1825): 1573, 0, 1
# Last time info (seed = 1493): 462, 0, 1112
# Last time info (seed = 1496): 1573, 0, 1
# Last time info (seed = 1507): 1573, 0, 1
# Last time info (seed = 1584): 390, 0, 1184
# Last time info (seed = 1535): 1573, 0, 1
# Last time info (seed = 1545): 465, 0, 1109
# Last time info (seed = 1550): 1573, 0, 1
# Last time info (seed = 1564): 1573, 0, 1
# Last time info (seed = 1569): 1573, 0, 1
# Last time info (seed = 183): 395, 0, 1179
# Last time info (seed = 404): 1573, 0, 1
# Last time info (seed = 606): 1573, 0, 1
# Last time info (seed = 722): 374, 0, 1200
# Last time info (seed = 1087): 1573, 0, 1
# Last time info (seed = 1434): 389, 0, 1185
# Last time info (seed = 1621): 423, 0, 1151
# Last time info (seed = 1673): 1573, 0, 1
# Last time info (seed = 1581): 453, 0, 1121
# Last time info (seed = 1589): 1573, 0, 1
# Last time info (seed = 1605): 444, 0, 1130
# Last time info (seed = 1619): 1573, 0, 1
# Last time info (seed = 1663): 455, 0, 1119
# Last time info (seed = 1676): 1572, 0, 2
# Last time info (seed = 1586): 1573, 0, 1
# Last time info (seed = 1708): 1572, 0, 2
# Last time info (seed = 1726): 1573, 0, 1
# Last time info (seed = 1745): 1561, 0, 13
# Last time info (seed = 1854): 400, 0, 1174
# Last time info (seed = 1856): 405, 0, 1169
# Last time info (seed = 1727): 1573, 0, 1
# Last time info (seed = 1769): 1573, 0, 1
# Last time info (seed = 1770): 379, 0, 1195
# Last time info (seed = 1775): 1573, 0, 1
# Last time info (seed = 1398): 1573, 0, 1
# Last time info (seed = 1794): 1573, 0, 1
# Last time info (seed = 1415): 1573, 0, 1
# Last time info (seed = 1832): 1572, 0, 2

# %%
deg_corr = stat.correlation(R_rate_list, degree_list)
bet_corr = stat.correlation(R_rate_list, bet_list)
eigen_corr = stat.correlation(R_rate_list, eigen_list)
close_corr = stat.correlation(R_rate_list, close_list)

# %%
print('Comparação entre medidas da rede e fração de recuperados para seed nodes')
print('Grau médio: ', deg_corr)
print('Betweeness: ', bet_corr)
print('Eigenvector ctl.: ', eigen_corr)
print('Closeness: ', close_corr)
# Out:
# Comparação entre medidas da rede e fração de recuperados para seed nodes
# Grau médio:  0.288515249096329
# Betweeness:  0.28228241575511237
# Eigenvector ctl.:  0.28228241575511237
# Closeness:  0.37126573518904266

# %% [markdown]
# A maior correlação foi encontrada na medida de Closeness Centrality. Pela definição, essa medida indica a proximidade do nó em relação à outros, e portanto, a correlação se mostra bem condizente.

# %% [markdown]
# <hr>

# %% [markdown]
# **5 -** Gere redes do tipo BA, ER e WS (p=0.05) com grau médio igual a 10 e N = 500. Desenvolva um estudo para mostrar que essas apresentam topologias diferentes. (Seja criativ@).

# %% [markdown]
# Disclaimer: como já realizado no trabalho de classificação de redes, poderia ter gerado várias redes e realizado o PCA, porém tentei fazer algo diferente utilizando o que aprendemos ao longo da matéria.

# %% [markdown]
# Primeiro são definidas funções para analisar redes BA, ER e WS.

# %%
import itertools
import collections

def ff3(x):
    return x*(x-1)*(x-2)

def avg_tetr_cc(g):
    tetrahedra = itertools.islice(itertools.groupby(
        nx.enumerate_all_cliques(g), len), 3, 4)
    try:
        tetrahedra = next(tetrahedra)[1]
    except StopIteration:
        return 0
    cnts = collections.Counter(itertools.chain(*tetrahedra))
    return 6 * sum(cnt / ff3(g.degree[v]) for v, cnt in cnts.items()) / len(g)

# %%
def community_layout(g, partition):
    """
    Compute the layout for a modular graph.


    Arguments:
    ----------
    g -- networkx.Graph or networkx.DiGraph instance
        graph to plot

    partition -- dict mapping int node -> int community
        graph partitions


    Returns:
    --------
    pos -- dict mapping int node -> (float x, float y)
        node positions

    """

    pos_communities = _position_communities(g, partition, scale=3.)

    pos_nodes = _position_nodes(g, partition, scale=1.)

    # combine positions
    pos = dict()
    for node in g.nodes():
        pos[node] = pos_communities[node] + pos_nodes[node]

    return pos

def _position_communities(g, partition, **kwargs):

    # create a weighted graph, in which each node corresponds to a community,
    # and each edge weight to the number of edges between communities
    between_community_edges = _find_between_community_edges(g, partition)

    communities = set(partition.values())
    hypergraph = nx.DiGraph()
    hypergraph.add_nodes_from(communities)
    for (ci, cj), edges in between_community_edges.items():
        hypergraph.add_edge(ci, cj, weight=len(edges))

    # find layout for communities
    pos_communities = nx.spring_layout(hypergraph, **kwargs)

    # set node positions to position of community
    pos = dict()
    for node, community in partition.items():
        pos[node] = pos_communities[community]

    return pos

def _find_between_community_edges(g, partition):

    edges = dict()

    for (ni, nj) in g.edges():
        ci = partition[ni]
        cj = partition[nj]

        if ci != cj:
            try:
                edges[(ci, cj)] += [(ni, nj)]
            except KeyError:
                edges[(ci, cj)] = [(ni, nj)]

    return edges

def _position_nodes(g, partition, **kwargs):
    """
    Positions nodes within communities.
    """

    communities = dict()
    for node, community in partition.items():
        try:
            communities[community] += [node]
        except KeyError:
            communities[community] = [node]

    pos = dict()
    for ci, nodes in communities.items():
        subgraph = g.subgraph(nodes)
        pos_subgraph = nx.spring_layout(subgraph, **kwargs)
        pos.update(pos_subgraph)

    return pos

def plot_with_communities(G):
    # to install networkx 2.0 compatible version of python-louvain use:
    # pip install -U git+https://github.com/taynaud/python-louvain.git@networkx2
    from community import community_louvain

    partition = community_louvain.best_partition(G)
    pos = community_layout(G, partition)
    
    d = dict(G.degree)
    
    nx.draw_networkx_nodes(G, pos, node_color=list(partition.values()), 
                           node_size=[1*v for v in d.values()])
    plt.show()
    return

# %%
def plot_attacks(G, attack_type):
  if attack_type != "targeted" and attack_type != "random":
    print("Possible attack types: 'targeted' and 'random'.")
    return

  C = G.copy()
  N = C.number_of_nodes()
  number_of_steps = 25
  M = N // number_of_steps
  random_attack_core_proportions = []
  num_nodes_removed = range(0, N, M)
  for nodes_removed in num_nodes_removed:
      # Measure the relative size of the network core
      core = next(nx.connected_components(C))
      core_proportion = len(core) / N
      random_attack_core_proportions.append(core_proportion)
      
      # If there are more than M nodes, select M nodes at random and remove them
      if C.number_of_nodes() > M:
        if attack_type == "random":
          nodes_to_remove = random.sample(list(C.nodes), M)
          C.remove_nodes_from(nodes_to_remove)
        elif attack_type == "targeted":
          nodes_sorted_by_degree = sorted(C.nodes, key=C.degree, reverse=True)
          nodes_to_remove = nodes_sorted_by_degree[:M]
          C.remove_nodes_from(nodes_to_remove)
  
  plt.title(attack_type)
  plt.xlabel('Number of nodes removed')
  plt.ylabel('Proportion of nodes in core')
  plt.plot(num_nodes_removed, random_attack_core_proportions, marker='o')

# %%
from collections import Counter

class Graph():
  def __init__(self, graph, name):
    self.G = graph
    self.name = name
    self.deg_list = [self.G.degree(n) for n in self.G.nodes()]
    self.nodes = nx.number_of_nodes(self.G)
    self.edges = nx.number_of_edges(self.G)
    self._density = nx.density(self.G)
    self._da_coeff = nx.degree_assortativity_coefficient(self.G)
    if(nx.is_connected(self.G)):
      self._spl_mean = nx.average_shortest_path_length(self.G)
    else:
      closeness_centr = nx.closeness_centrality(self.G)
      self._spl_mean = stat.mean(closeness_centr)
    nodes_clustering = nx.clustering(self.G)
    self._c_mean = stat.mean(nodes_clustering.values())
    self._c_stdev = stat.stdev(nodes_clustering.values())
    self._dg_mean = stat.mean(self.deg_list)
    self._dg_stdev = stat.stdev(self.deg_list)
    self.dg_median = stat.median(self.deg_list)
    betweenness = nx.betweenness_centrality(self.G)
    self.betweenness_sequence = list(betweenness.values())
    self._bt_mean = stat.mean(self.betweenness_sequence)
    self._bt_stdev = stat.stdev(self.betweenness_sequence)
    self._bt_median = stat.median(self.betweenness_sequence)

  def bgm(self):
    print(self.name) 
    print("Nodes:", self.nodes)
    print("Links:", self.edges)
    print("Density:", self._density)
    print("Degree mean: ", self._dg_mean)
    print("Degree standart deviation: ", self._dg_stdev)
    

  def swm(self):
    print("Small world measures: ") 
    print("Assortativity by degree:", self._da_coeff)
    print("Average shortest path lenght:", self._spl_mean)

  def plot(self):
    nx.draw(self.G, node_size=2)

  def deg_graph(self):
    k, Pk = degree_distribution(self.G)
    inv_cumsum = 1 - np.cumsum(Pk)
    fig, ax = plt.subplots()
    plt.loglog(k, inv_cumsum, 'o')

    plt.title(f"{self.name} model")
    plt.ylabel("Inverso da cumulativa de $P(k)$")
    plt.xlabel("$k$")
    plt.show()

    
  def centrality(self):
    #centrality distributions
    print("Centrality: ")
    print("Mean degree:", self._dg_mean)
    print("Median degree:", self.dg_median)
    print("Mean betweenness:", self._bt_mean)
    print("Median betweenness:", self._bt_median)
    #plots
    degree_counts = Counter(self.deg_list)
    plt.ylabel("N of nodes")
    plt.xlabel("Betweenness")
    plt.hist(self.betweenness_sequence)
    if(self.name == "Barabasi-Albert"):
        plt.yscale('log')
    plt.grid(True)
    plt.show()
    
  def robustness(self):
    #robustness
    plt.figure(1)
    plot_attacks(self.G, "random")
    plt.figure(2)
    plot_attacks(self.G, "targeted")
    plt.show()
  
  def core(self):
    #tried to simplify the graph with a core decomposition
    plt.figure(3)
    n = nx.number_of_nodes(self.G)
    net = self.G
    k = 1
    nodes_after_dec = n #nodes after decomposition
    while(nodes_after_dec != 0):
      oldNet = net
      net = nx.k_core(net, k)
      k += 1
      nodes_after_dec = nx.number_of_nodes(net)
    pos = nx.spring_layout(oldNet)
    nx.draw_networkx_nodes(oldNet, pos, node_size=20)
    nx.draw_networkx_edges(oldNet, pos, alpha=0.2)
    plt.plot()
    plt.show()
    
    
  def clustering(self):
    print('Clustering: ') 
    print("Clustering coefficient:", self._c_mean)
    print("Clustering standart deviation", self._c_stdev)
    self.avg_tetrahedron_cc = avg_tetr_cc(self.G)
    print("Tetrahedron Clustering: ", self.avg_tetrahedron_cc)

# %%
nodes = 500
k = 10
m = int(k/2)
p = k/(nodes-1)

er_graph = Graph(nx.erdos_renyi_graph(nodes, p), "Erdos-Renyi")
ws_graph = Graph(nx.watts_strogatz_graph(nodes, k, p), "Watts-Strogatz")
ba_graph = Graph(nx.barabasi_albert_graph(nodes, m), "Barabasi-Albert")

# %% [markdown]
# Nas medidas geradas, começamos com uma *decomposição k-core*, que permite visualizar o núcleo de maior grau do gráfico.
#
# Logo em seguida, plotamos um gráfico que mostra como é feita a *distribuição dos graus nos nós*.
#
# Então seguem medidas de *clustering*, includindo clustering de tetraedros, que buscam mostrar o quão agrupada a rede está. Essas estruturas são muito presentes em Álgebra Topológica.
#
# Há um plot da rede com a *divisão de comunidades* realizadas através do algoritmo de Louvain - os tamanhos dos nós indicam o grau. Aqui buscamos apenas uma visualização da disposição da rede, e não de medidas.
#
# Para buscar entender a topologia da rede, há um *teste de robustez*, com ataques direcionados e aleatórios.
#
# Vamos então gerar os grafos.

# %%
er_graph.core()
ws_graph.core()
ba_graph.core()

# %%
er_graph.deg_graph()
ws_graph.deg_graph()
ba_graph.deg_graph()

# %% [markdown]
# Após visualizar uma prévia da rede podemos ver a distribuição do grau. Nos dois primeiros grafos há uma distribuição semelhante a normal. No gráfico da rede BA notamos a presença de uma cauda, indicando a presença de Hubs.

# %%
er_graph.clustering()
ws_graph.clustering()
ba_graph.clustering()

# %% [markdown]
# Ao checar as medidas de clustering, vemos que são pequenas em ER e BA, mas grandes na rede Watts-Strogatz, devido a natureza da rede, mostrando que a rede é bem emaranhada.

# %%
plot_with_communities(er_graph.G)
plot_with_communities(ws_graph.G)
plot_with_communities(ba_graph.G)

# %% [markdown]
# O gráfico com a disposição das comunidas busca mostrar as divisões. Além disso, a rede BA apresenta Hubs de acordo com a imagem, como previsto no primeiro gráfico, sendo que esses Hubs ajudam a dividir a rede em comunidades.

# %%
er_graph.robustness()

# %%
ws_graph.robustness()

# %%
ba_graph.robustness()

# %% [markdown]
# Por fim, ao realizar os ataques, percebemos que as redes com mais Hubs são mais suscetíveis a ataques/falhas.

# %% [markdown]
# Podemos concluir que cada uma das 3 redes aleatórias possui uma característica de destaque.
# As redes Watts-Strogatz apresentam alto grau de clusterização, já as redes Barabási-Albert apresentam Hubs bem definidos. Enquanto isso, o Erdos Renyi não possui características por conta de sua geração por um processo totalmente aleatório: é mediano em diversos parâmetros.
